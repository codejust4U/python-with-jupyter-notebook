# %%
import numpy as np
import pandas as pd
data1= {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}

df1 = pd.DataFrame(data1)

df1.isnull()
# Out:
#    First Score  Second Score  Third Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
data2 = pd.read_csv(r'D:\excel_datas\day5\employees.csv')

bool_s_1 = pd.isnull(data2["Gender"])
data2[bool_s_1]
# Out:
#     First Name Gender  Start Date Last Login Time  Salary  Bonus %
# 20        Lois    NaN   4/22/1995         7:18 PM   64714    4.934  \
# 22      Joshua    NaN    3/8/2012         1:58 AM   90816   18.816
# 27       Scott    NaN   7/11/1991         6:58 PM  122367    5.218
# 31       Joyce    NaN   2/20/2005         2:40 PM   88657   12.752
# 41   Christine    NaN   6/28/2015         1:08 AM   66582   11.308
# ..         ...    ...         ...             ...     ...      ...
# 961    Antonio    NaN   6/18/1989         9:37 PM  103050    3.050
# 972     Victor    NaN   7/28/2006         2:49 PM   76381   11.159
# 985    Stephen    NaN   7/10/1983         8:10 PM   85668    1.909
# 989     Justin    NaN   2/10/1991         4:58 PM   38344    3.794
# 995      Henry    NaN  11/23/2014         6:09 AM  132483   16.655
#
#     Senior Management                  Team
# 20               True                 Legal
# 22               True       Client Services
# ...

# %%
    
data3 = pd.read_csv(r'D:\excel_datas\day5\employees.csv')

bool_s_2 = pd.notnull(data3["Gender"])

bool_s_2
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
data4 = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
bool_s_3 = pd.DataFrame(data4)

bool_s_3.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %% [markdown]
# Filling null values with the previous ones

# %%
bool_s_3.fillna(method='pad')
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2         90.0          56.0         80.0
# 3         95.0          56.0         98.0

# %% [markdown]
# Filling null value with the next ones

# %%
bool_s_3.fillna(method='bfill')
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %% [markdown]
# Now we are going to fill all the null values in Gender column with “No Gender”

# %%
data5 = pd.read_csv(r'D:\excel_datas\day5\employees.csv')

data5["Gender"].fillna("No gender", inplace=True)

data5
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945  \
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %% [markdown]
# Now we are going to replace the all Nan value in the data frame with -99 value.

# %%
data5.replace(to_replace=np.nan, value=-99)
# Out:
#     First Name     Gender  Start Date Last Login Time  Salary  Bonus %
# 0      Douglas       Male    8/6/1993        12:42 PM   97308    6.945  \
# 1       Thomas       Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria     Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry       Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry       Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...        ...         ...             ...     ...      ...
# 995      Henry  No gender  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip       Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell       Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry       Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert       Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df5 = pd.DataFrame({"A":[12, 4, 5, None, 1], 
                   "B":[None, 2, 54, 3, None], 
                   "C":[20, 16, None, 3, 8], 
                   "D":[14, 3, None, None, 6]}) 

print(df5)
print("--------------------------------------------")


df5.interpolate(method='linear',limit_direction="forward")
# Out:
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   NaN   NaN
# 3   NaN   3.0   3.0   NaN
# 4   1.0   NaN   8.0   6.0
# --------------------------------------------
#       A     B     C     D
# 0  12.0   NaN  20.0  14.0
# 1   4.0   2.0  16.0   3.0
# 2   5.0  54.0   9.5   4.0
# 3   3.0   3.0   3.0   5.0
# 4   1.0   3.0   8.0   6.0

# %% [markdown]
# Now we drop a rows whose all data is missing or contain null values(NaN)

# %%
data6 = {'First Score':[100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, np.nan, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

df6 = pd.DataFrame(data6)
print(df6)

print("--------------------------------------------")

df6 = pd.DataFrame(data6)
df6.dropna(how='all')
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0           NaN
# 1          NaN           NaN          NaN           NaN
# 2          NaN          45.0         80.0           NaN
# 3         95.0          56.0         98.0          65.0
# --------------------------------------------
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0         52.0           NaN
# 2          NaN          45.0         80.0           NaN
# 3         95.0          56.0         98.0          65.0

# %%
data7 = {'First Score':[100, np.nan, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, np.nan, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}
new_data = data6.dropna(axis = 0, how ='any') 

new_data
