# %%
import pandas as pd

print("--------------------------Creating a dataframe in pandas------------------------")
# Creating a DataFrame using a list
list1 = ['pankaj','ravi','subash','amanuwell','gulshan','naman','samir','rahul']

dataframe1 = pd.DataFrame(list1)
print(dataframe1)
# Out:
# --------------------------Creating a dataframe in pandas------------------------
#            0
# 0     pankaj
# 1       ravi
# 2     subash
# 3  amanuwell
# 4    gulshan
# 5      naman
# 6      samir
# 7      rahul

# %%
import numpy as np

# %%
list2 = {
    'Name' : ['pankaj','ravi','subash','amanuwell','gulshan','naman','samir','rahul'],
    'Age' : [23,22,21,23,22,20,22,20],
    'Id' : [11,12,13,14,15,16,17,18]
}
dataframe2 = pd.DataFrame(list2)
print(dataframe2)
# Out:
#         Name  Age  Id
# 0     pankaj   23  11
# 1       ravi   22  12
# 2     subash   21  13
# 3  amanuwell   23  14
# 4    gulshan   22  15
# 5      naman   20  16
# 6      samir   22  17
# 7      rahul   20  18

# %%
list3 = {
    'Name' : ['pankaj','ravi','subash','amanuwell','gulshan','naman','samir','rahul'],
    'Age' : [23,22,21,23,22,20,22,20],
    'Id' : [11,12,13,14,15,16,17,18]
}
dataframe3 = pd.DataFrame(list3)
print("-------------------------------Printing only ages-------------------------------")
print(dataframe3[['Age']])
# Out:
# -------------------------------Printing only ages-------------------------------
#    Age
# 0   23
# 1   22
# 2   21
# 3   23
# 4   22
# 5   20
# 6   22
# 7   20

# %%
"""
Row Selection: Pandas provide a unique method to retrieve rows from a Data frame. DataFrame.loc[] method is used to retrieve rows from Pandas DataFrame. Rows can also be selected by passing integer location to an iloc[] function.

Note: We’ll be using nba.csv file in below examples.
"""
try:
    datas = pd.read_csv(r'D:\excel_datas\day1\students - Sheet1.csv')
    print(datas)
    #first = datas.loc["Mike"]
    #print(first)
except:
    print("connection failed")
# Out:
#           id first_name last_name date_of_birth               ethnicity
# 0   111111.0       John       Doe       01/2000                Hispanic  \
# 1   111112.0       Jane     Smith       05/2001                Hispanic
# 2   111113.0      Sarah    Thomas       21/2002                Hispanic
# 3   111114.0      Frank     Brown       13/2002  Race/ethnicity unknown
# 4   111115.0       Mike     Davis       31/2001                   White
# 5   111116.0   Jennifer    Wilson       01/2002                   Asian
# 6   111117.0    Jessica    Garcia       01/2000                   White
# 7   111118.0       Fred     Clark       17/1999                Hispanic
# 8   111119.0        Bob     Lopez       04/1998                   White
# 9        NaN        NaN       NaN           NaN                     NaN
# 10       NaN        NaN       NaN           NaN                     NaN
# 11       NaN        NaN       NaN           NaN                     NaN
# ...

# %%
try:
    datas = pd.read_csv(r'D:\excel_datas\day1\students - Sheet1.csv',index_col='first_name')
    print(datas)
    first = datas['date_of_birth']
    print(first)
except:
    print("connection failed")
# Out:
#                   id last_name date_of_birth               ethnicity gender
# first_name
# John        111111.0       Doe       01/2000                Hispanic      M  \
# Jane        111112.0     Smith       05/2001                Hispanic      F
# Sarah       111113.0    Thomas       21/2002                Hispanic      M
# Frank       111114.0     Brown       13/2002  Race/ethnicity unknown      M
# Mike        111115.0     Davis       31/2001                   White      F
# Jennifer    111116.0    Wilson       01/2002                   Asian      M
# Jessica     111117.0    Garcia       01/2000                   White      F
# Fred        111118.0     Clark       17/1999                Hispanic      F
# Bob         111119.0     Lopez       04/1998                   White      F
# NaN              NaN       NaN           NaN                     NaN    NaN
# NaN              NaN       NaN           NaN                     NaN    NaN
# ...

# %%
import numpy as np
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Third Score':[np.nan, 40, 80, 98]}
 
# creating a dataframe from dictionary
df = pd.DataFrame(dict)
 
# filling missing value using fillna()  
df.fillna('Nan')
# Out:
#   First Score Second Score Third Score
# 0       100.0         30.0         Nan
# 1        90.0         45.0        40.0
# 2         Nan         56.0        80.0
# 3        95.0          Nan        98.0

# %%
import pandas as pd
dictionary1 = {
    "Id" : [101,102,103,104,105],
    "Name" : ["Pankaj","Ravi","Amanuwell","Subash","Gulshan"],
    "Roll no" : [50,59,9,65,34]
}
dataframe4 = pd.DataFrame(dictionary1)
print(dataframe4)
# Out:
#     Id       Name  Roll no
# 0  101     Pankaj       50
# 1  102       Ravi       59
# 2  103  Amanuwell        9
# 3  104     Subash       65
# 4  105    Gulshan       34

# %%
dictionary2 = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}
dataframe5 = pd.DataFrame(dictionary2)
print(dataframe5)

dataframe5.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
"""
terating over rows and columns
Iteration is a general term for taking each item of something, one after another. Pandas DataFrame consists of rows and columns so, in order to iterate over dataframe, we have to iterate a dataframe like a dictionary.

Iterating over rows :
In order to iterate over rows, we can use three function iteritems(), iterrows(), itertuples() . These three function will help in iteration over rows.
"""
# dictionary of lists
dictionary3 = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}
 
# creating a dataframe from a dictionary 
dataframe6 = pd.DataFrame(dictionary3)
 
# iterating over rows using iterrows() function 
for i, j in dataframe6.iterrows():
    print(i, j)
    print()
# Out:
# 0 name      aparna
# degree       MBA
# score         90
# Name: 0, dtype: object
#
# 1 name      pankaj
# degree       BCA
# score         40
# Name: 1, dtype: object
#
# 2 name      sudhir
# degree    M.Tech
# score         80
# Name: 2, dtype: object
#
# 3 name      Geeku
# degree      MBA
# score        98
# Name: 3, dtype: object
