# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_excel(r'D:\copy of htdocs\practice\Python\200days\Day148 Statistics-Day2\data.xlsx')
df
# Out:
#    data
# 0     6
# 1   213
# 2   241
# 3   260
# 4   281
# 5   290
# 6   314
# 7   321
# 8   350
# 9  1500

# %%
plt.plot(df)

# %% [markdown]
# ### 5 number summary helps in identifying outliers

# %%
df['data'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['data'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2=pd.read_excel(r'D:\copy of htdocs\practice\Python\200days\Day148 Statistics-Day2\data2.xlsx')
df2
# Out:
#    Price(in Lakhs)  House (in sq. ft)
# 0             60.0               1300
# 1             80.0               1500
# 2             75.0               1450
# 3             98.0               2000
# 4              1.5               2500

# %%
plt.scatter(df2['Price(in Lakhs)'],df2['House (in sq. ft)'],color='green')

plt.plot(df2['Price(in Lakhs)'],df2['House (in sq. ft)'],color='red')

# %% [markdown]
# ----
# -----

# %% [markdown]
# ### Covariance

# %% [markdown]
# ![WhatsApp Image 2023-07-25 at 21.40.30.jpg](<attachment:WhatsApp Image 2023-07-25 at 21.40.30.jpg>)

# %%
df3=pd.read_excel(r'D:\copy of htdocs\practice\Python\200days\Day148 Statistics-Day2\covariance_data.xlsx')
df3
# Out:
#     X   Y  X-Xmean  Y-Ymean  (X-Xmean)*(Y-Ymean)
# 0   2   1       -6       -5                   30
# 1   5   2       -3       -4                   12
# 2   8   5        0       -1                    0
# 3  12  12        4        6                   24
# 4  13  10        5        4                   20

# %% [markdown]
# this is the example of positive covarinace if the data lies in 1st and 3rd quarter

# %%
import numpy as np

# %%
fig, (ax1,ax2) =plt.subplots(1,2,figsize=(10,3))

ax1.scatter(df3['X'],df3['Y'])
ax2.scatter(df3['X'],df3['X'],color='purple')


ax1.set_title("Covariance = "+str(np.cov(df3['X'],df3['Y'])[0,1]))
ax2.set_title("Covariance = "+str(np.cov(df3['X'],df3['X'])[0,1]))
# Out:
# Text(0.5, 1.0, 'Covariance = 21.5')

# %% [markdown]
# ### -ve covariance
# ![WhatsApp Image 2023-07-25 at 21.50.06.jpg](<attachment:WhatsApp Image 2023-07-25 at 21.50.06.jpg>)

# %%
df4=pd.read_excel(r'D:\copy of htdocs\practice\Python\200days\Day148 Statistics-Day2\neg_covariance.xlsx')
df4
# Out:
#     X   Y  X-Xmean  Y-Ymean  (X-Xmean)*(Y-Ymean)
# 0   2  10       -6        4                  -24
# 1   5  12       -3        6                  -18
# 2   8   5        0       -1                    0
# 3  12   2        4       -4                  -16
# 4  13   1        5       -5                  -25

# %%
plt.scatter(df4['X'],df4['Y'])

# %% [markdown]
# ----
# -----

# %% [markdown]
# ### Correlation

# %%
fig, (ax1,ax2) =plt.subplots(1,2,figsize=(10,3))

ax1.scatter(df3['X'],df3['Y'])
ax2.scatter(df3['X']*2,df3['Y'])


ax1.set_title("Correlation : "+str(df3['X'].corr(df3['Y'])))
ax2.set_title("Correlation : "+str((df3['X']*2).corr(df3['Y']*2)))
# Out:
# Text(0.5, 1.0, 'Correlation : 0.9565007145952775')

# %% [markdown]
# ### Correlation is still the same on both the plots which means correlation isnt dependent on scale of data

# %% [markdown]
# ![WhatsApp Image 2023-07-25 at 22.40.27.jpg](<attachment:WhatsApp Image 2023-07-25 at 22.40.27.jpg>)

# %% [markdown]
# ----
# -----
