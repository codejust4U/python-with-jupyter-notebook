# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"D:\datas\excel\Day15\Book3.csv")
data
# Out:
#          cgpa        Age      Weight       Salary
# 0   27.900000  33.000000   80.000000  1500.000000
# 1   33.770000  33.000000   82.500000  1200.000000
# 2   33.000000  34.000000  100.800000  2200.000000
# 3   22.705000  42.000000   90.000000  2100.000000
# 4   28.880000  29.000000   67.000000  1500.000000
# 5   25.740000  19.000000   60.000000  1700.000000
# 6   33.440000  50.000000   77.000000  3000.000000
# 7   27.740000  36.857143   77.000000  3000.000000
# 8   29.830000  37.500000   87.000000  2800.000000
# 9   25.840000  38.142857   70.000000  2900.000000
# 10  26.220000  38.785714   57.000000  2780.000000
# 11  26.290000  39.428571   64.000000  2550.000000
# 12  26.267273  40.071429   62.636364  3177.454545
# 13  25.932045  40.714286   60.576573  3317.181818
# 14  25.596818  41.357143   58.516783  3456.909091
# 15  25.261591  42.000000   56.456993  3596.636364
# 16  24.926364  42.642857   54.397203  3736.363636
# 17  24.591136  43.285714   52.337413  3876.090909
# ...

# %%
data.dropna()
# Out:
#          cgpa        Age      Weight       Salary
# 0   27.900000  33.000000   80.000000  1500.000000
# 1   33.770000  33.000000   82.500000  1200.000000
# 2   33.000000  34.000000  100.800000  2200.000000
# 3   22.705000  42.000000   90.000000  2100.000000
# 4   28.880000  29.000000   67.000000  1500.000000
# 5   25.740000  19.000000   60.000000  1700.000000
# 6   33.440000  50.000000   77.000000  3000.000000
# 7   27.740000  36.857143   77.000000  3000.000000
# 8   29.830000  37.500000   87.000000  2800.000000
# 9   25.840000  38.142857   70.000000  2900.000000
# 10  26.220000  38.785714   57.000000  2780.000000
# 11  26.290000  39.428571   64.000000  2550.000000
# 12  26.267273  40.071429   62.636364  3177.454545
# 13  25.932045  40.714286   60.576573  3317.181818
# 14  25.596818  41.357143   58.516783  3456.909091
# 15  25.261591  42.000000   56.456993  3596.636364
# 16  24.926364  42.642857   54.397203  3736.363636
# 17  24.591136  43.285714   52.337413  3876.090909
# ...

# %%
X=data.drop(["Salary"],axis=1).values
y=data["Salary"].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
mlreg=LinearRegression()

# %%
mlreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=mlreg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9188234719918503

# %%
mlreg.coef_
# Out:
# array([-18.22819545,  84.00885745, -30.63617389])

# %%
mlreg.intercept_
# Out:
# 2280.621954783274

# %%
plt.plot(X_test,y_test,".",label="Actual_value",color="blue")
plt.plot(X_test,y_pred,label="Predicted_value",color="red")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
