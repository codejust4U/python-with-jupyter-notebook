# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - reading the data

# %%
df=pd.read_csv(r'Clean_Top_1000_Youtube_df - youtubers_df.csv')

# %%
df
# Out:
#      Rank              Username     Categories   Suscribers Country  \
# 0       1               tseries  Entertainment  249,500,000      IN
# 1       2               MrBeast  Entertainment  183,500,000      US
# 2       3             CoComelon          Music  165,500,000      US
# 3       4              SETIndia  Entertainment  162,600,000      IN
# 4       5         KidsDianaShow          Hobby  113,500,000      US
# ..    ...                   ...            ...          ...     ...
# 995   996          hamzymukbang           Food   11,700,000      KR
# 996   997            Adaahqueen           Film   11,700,000      IN
# 997   998  LittleAngelIndonesia  Entertainment   11,700,000      ID
# 998   999          PenMultiplex           Film   11,700,000      IN
# 999  1000         OneindiaHindi        Society   11,700,000      IN
#
#           Visits      Likes Comments  \
# 0         86,200      2,700       78
# 1    117,400,000  5,300,000   18,500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  1000 non-null   object
#  3   Suscribers  1000 non-null   object
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   object
#  6   Likes       1000 non-null   object
#  7   Comments    1000 non-null   object
#  8   Links       1000 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Rank          0
# Username      0
# Categories    0
# Suscribers    0
# Country       0
# Visits        0
# Likes         0
# Comments      0
# Links         0
# dtype: int64

# %% [markdown]
# - working on categories

# %%
df['Categories'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Categories'>

# %%
df['Type<25']=df['Categories'].value_counts()<25

# %%
df['Type<25']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 995    NaN
# 996    NaN
# 997    NaN
# 998    NaN
# 999    NaN
# Name: Type<25, Length: 1000, dtype: object

# %%
sns.histplot(df['Categories'])
# Out:
# c:\Users\panka\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\panka\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\panka\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Categories', ylabel='Count'>

# %%
len(df['Categories'])<35
# Out:
# False

# %%
df['Type<35']=df['Categories'].value_counts()

# %%
df
# Out:
#      Rank              Username     Categories   Suscribers Country  \
# 0       1               tseries  Entertainment  249,500,000      IN
# 1       2               MrBeast  Entertainment  183,500,000      US
# 2       3             CoComelon          Music  165,500,000      US
# 3       4              SETIndia  Entertainment  162,600,000      IN
# 4       5         KidsDianaShow          Hobby  113,500,000      US
# ..    ...                   ...            ...          ...     ...
# 995   996          hamzymukbang           Food   11,700,000      KR
# 996   997            Adaahqueen           Film   11,700,000      IN
# 997   998  LittleAngelIndonesia  Entertainment   11,700,000      ID
# 998   999          PenMultiplex           Film   11,700,000      IN
# 999  1000         OneindiaHindi        Society   11,700,000      IN
#
#           Visits      Likes Comments  \
# 0         86,200      2,700       78
# 1    117,400,000  5,300,000   18,500
# ...

# %%
df['Categories'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Type<35'].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Type<35, dtype: float64

# %%
df['Suscribers'].describe()
# Out:
# count           1000
# unique           276
# top       12,600,000
# freq              31
# Name: Suscribers, dtype: object

# %%
df['Suscribers'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Suscribers
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
df['Suscribers'] = df['Suscribers'].str.replace(',', '', regex=True).astype('int64')

# %%
df['Suscribers'].describe()
# Out:
# count    1.000000e+03
# mean     2.199870e+07
# std      1.686848e+07
# min      1.170000e+07
# 25%      1.380000e+07
# 50%      1.680000e+07
# 75%      2.382500e+07
# max      2.495000e+08
# Name: Suscribers, dtype: float64

# %%
df['Suscribers'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#      Rank              Username     Categories  Suscribers Country  \
# 0       1               tseries  Entertainment   249500000      IN
# 1       2               MrBeast  Entertainment   183500000      US
# 2       3             CoComelon          Music   165500000      US
# 3       4              SETIndia  Entertainment   162600000      IN
# 4       5         KidsDianaShow          Hobby   113500000      US
# ..    ...                   ...            ...         ...     ...
# 995   996          hamzymukbang           Food    11700000      KR
# 996   997            Adaahqueen           Film    11700000      IN
# 997   998  LittleAngelIndonesia  Entertainment    11700000      ID
# 998   999          PenMultiplex           Film    11700000      IN
# 999  1000         OneindiaHindi        Society    11700000      IN
#
#           Visits      Likes Comments  \
# 0         86,200      2,700       78
# 1    117,400,000  5,300,000   18,500
# 2      7,000,000     24,700        0
# ...

# %%
df['Visits'] = df['Visits'].str.replace(',', '', regex=True).astype('int64')

# %%
df['Visits'].describe()
# Out:
# count    1.000000e+03
# mean     1.208789e+06
# std      5.230081e+06
# min      0.000000e+00
# 25%      2.942500e+04
# 50%      1.739500e+05
# 75%      8.654750e+05
# max      1.174000e+08
# Name: Visits, dtype: float64

# %%
df['Country'].describe()
# Out:
# count     1000
# unique      53
# top         US
# freq       321
# Name: Country, dtype: object
