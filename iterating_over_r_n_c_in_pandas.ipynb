# %%
import pandas as pd
data1 = pd.read_csv(r'D:\excel_datas\day1\students - Sheet1.csv')

df1 = pd.DataFrame(data1)

df1

# %%
import pandas as pd
data2 = pd.read_csv(r'D:\excel_datas\day1\students - Sheet1.csv')

df2 = pd.DataFrame(data2)
for i,j in df2.iterrows():
    print(i,j)
    print()

# %%
df3 = data2.head(10)
df3
# Out:
#          id first_name last_name date_of_birth               ethnicity gender
# 0  111111.0       John       Doe       01/2000                Hispanic      M  \
# 1  111112.0       Jane     Smith       05/2001                Hispanic      F
# 2  111113.0      Sarah    Thomas       21/2002                Hispanic      M
# 3  111114.0      Frank     Brown       13/2002  Race/ethnicity unknown      M
# 4  111115.0       Mike     Davis       31/2001                   White      F
# 5  111116.0   Jennifer    Wilson       01/2002                   Asian      M
# 6  111117.0    Jessica    Garcia       01/2000                   White      F
# 7  111118.0       Fred     Clark       17/1999                Hispanic      F
# 8  111119.0        Bob     Lopez       04/1998                   White      F
# 9       NaN        NaN       NaN           NaN                     NaN    NaN
#
#      status entry_academic_period  exclusion_type  act_composite  ...
# 0        FT             Fall 2008             NaN            NaN  ...  \
# 1  TRANSFER             Fall 2006             NaN            NaN  ...
# 2      FTFT             Fall 2006             NaN           14.0  ...
# 3      FTFT             Fall 2006             NaN            NaN  ...
# 4      FTFT             Fall 2007             NaN           22.0  ...
# 5  TRANSFER             Fall 2006             NaN            NaN  ...
# 6      FTFT             Fall 2007             NaN           25.0  ...
# 7    FTGRAD             Fall 2010             NaN           21.0  ...
# 8      FTFT             Fall 2007             NaN           15.0  ...
# 9       NaN                   NaN             NaN            NaN  ...
#
#    sat_reading hs_gpa      hs_city    hs_state   hs_zip                email
# 0          NaN   2.71  Albuquerque  New Mexico  87112.0     jdoe@example.com  \
# 1          NaN   3.73     New York    New York  10009.0   jsmith@example.com
# 2          NaN   2.64      Pheonix     Arizona  85006.0  sthomas@example.com
# 3        210.0   3.68      Pheonix     Arizona  85015.0   fbrown@example.com
# 4          NaN   3.46      Seattle  Washington  98106.0   mdavis@example.com
# 5          NaN   4.24       Denver    Colorado  80012.0  jwilson@example.com
# 6          NaN    NaN       Austin       Texas  78703.0  jgarcia@example.com
# 7          NaN   2.54       Denver    Colorado  80033.0   fclark@example.com
# 8        220.0   3.24       Denver    Colorado  80122.0   blopez@example.com
# 9          NaN    NaN          NaN         NaN      NaN                  NaN
#
#    entry_age    ged english_2nd_language first_generation
# 0       17.9  False                False             True
# 1       18.1  False                False             True
# 2       17.6  False                False            False
# 3       19.0   True                False             True
# 4       18.2  False                 True            False
# 5       18.5   True                False             True
# 6       18.8  False                False            False
# 7       19.2  False                 True             True
# 8       18.5  False                False             True
# 9        NaN    NaN                  NaN              NaN
#
# [10 rows x 26 columns]

# %%
for i, j in df3.iterrows():
    print(i,j)
    print()
# Out:
# 0 id                               111111.0
# first_name                           John
# last_name                             Doe
# date_of_birth                     01/2000
# ethnicity                        Hispanic
# gender                                  M
# status                                 FT
# entry_academic_period           Fall 2008
# exclusion_type                        NaN
# act_composite                         NaN
# act_math                              NaN
# act_english                           NaN
# act_reading                           NaN
# sat_combined                          NaN
# sat_math                              NaN
# sat_verbal                            NaN
# sat_reading                           NaN
# hs_gpa                               2.71
# hs_city                       Albuquerque
# hs_state                       New Mexico
# hs_zip                            87112.0
# email                    jdoe@example.com
# entry_age                            17.9
# ged                                 False
# english_2nd_language                False
# first_generation                     True
# Name: 0, dtype: object
#
# 1 id                                 111112.0
# first_name                             Jane
# last_name                             Smith
# date_of_birth                       05/2001
# ethnicity                          Hispanic
# gender                                    F
# status                             TRANSFER
# entry_academic_period             Fall 2006
# exclusion_type                          NaN
# act_composite                           NaN
# act_math                                NaN
# act_english                             NaN
# act_reading                             NaN
# sat_combined                            NaN
# sat_math                                NaN
# sat_verbal                              NaN
# sat_reading                             NaN
# hs_gpa                                 3.73
# hs_city                            New York
# hs_state                           New York
# hs_zip                              10009.0
# email                    jsmith@example.com
# entry_age                              18.1
# ged                                   False
# english_2nd_language                  False
# first_generation                       True
# Name: 1, dtype: object
#
# 2 id                                  111113.0
# first_name                             Sarah
# last_name                             Thomas
# date_of_birth                        21/2002
# ethnicity                           Hispanic
# gender                                     M
# status                                  FTFT
# entry_academic_period              Fall 2006
# exclusion_type                           NaN
# act_composite                           14.0
# act_math                                 6.0
# act_english                                5
# act_reading                              3.0
# sat_combined                             NaN
# sat_math                                 NaN
# sat_verbal                               NaN
# sat_reading                              NaN
# hs_gpa                                  2.64
# hs_city                              Pheonix
# hs_state                             Arizona
# hs_zip                               85006.0
# email                    sthomas@example.com
# entry_age                               17.6
# ged                                    False
# english_2nd_language                   False
# first_generation                       False
# Name: 2, dtype: object
#
# 3 id                                     111114.0
# first_name                                Frank
# last_name                                 Brown
# date_of_birth                           13/2002
# ethnicity                Race/ethnicity unknown
# gender                                        M
# status                                     FTFT
# entry_academic_period                 Fall 2006
# exclusion_type                              NaN
# act_composite                               NaN
# act_math                                    NaN
# act_english                                 NaN
# act_reading                                 NaN
# sat_combined                             1450.0
# sat_math                                  520.0
# sat_verbal                                510.0
# sat_reading                               210.0
# hs_gpa                                     3.68
# hs_city                                 Pheonix
# hs_state                                Arizona
# hs_zip                                  85015.0
# email                        fbrown@example.com
# entry_age                                  19.0
# ged                                        True
# english_2nd_language                      False
# first_generation                           True
# Name: 3, dtype: object
#
# 4 id                                 111115.0
# first_name                             Mike
# last_name                             Davis
# date_of_birth                       31/2001
# ethnicity                             White
# gender                                    F
# status                                 FTFT
# entry_academic_period             Fall 2007
# exclusion_type                          NaN
# act_composite                          22.0
# act_math                               12.0
# act_english                               5
# act_reading                             5.0
# sat_combined                            NaN
# sat_math                                NaN
# sat_verbal                              NaN
# sat_reading                             NaN
# hs_gpa                                 3.46
# hs_city                             Seattle
# hs_state                         Washington
# hs_zip                              98106.0
# email                    mdavis@example.com
# entry_age                              18.2
# ged                                   False
# english_2nd_language                   True
# first_generation                      False
# Name: 4, dtype: object
#
# 5 id                                  111116.0
# first_name                          Jennifer
# last_name                             Wilson
# date_of_birth                        01/2002
# ethnicity                              Asian
# gender                                     M
# status                              TRANSFER
# entry_academic_period              Fall 2006
# exclusion_type                           NaN
# act_composite                            NaN
# act_math                                 NaN
# act_english                              NaN
# act_reading                              NaN
# sat_combined                             NaN
# sat_math                                 NaN
# sat_verbal                               NaN
# sat_reading                              NaN
# hs_gpa                                  4.24
# hs_city                               Denver
# hs_state                            Colorado
# hs_zip                               80012.0
# email                    jwilson@example.com
# entry_age                               18.5
# ged                                     True
# english_2nd_language                   False
# first_generation                        True
# Name: 5, dtype: object
#
# 6 id                                  111117.0
# first_name                           Jessica
# last_name                             Garcia
# date_of_birth                        01/2000
# ethnicity                              White
# gender                                     F
# status                                  FTFT
# entry_academic_period              Fall 2007
# exclusion_type                           NaN
# act_composite                           25.0
# act_math                                10.0
# act_english                                5
# act_reading                             10.0
# sat_combined                             NaN
# sat_math                                 NaN
# sat_verbal                               NaN
# sat_reading                              NaN
# hs_gpa                                   NaN
# hs_city                               Austin
# hs_state                               Texas
# hs_zip                               78703.0
# email                    jgarcia@example.com
# entry_age                               18.8
# ged                                    False
# english_2nd_language                   False
# first_generation                       False
# Name: 6, dtype: object
#
# 7 id                                 111118.0
# first_name                             Fred
# last_name                             Clark
# date_of_birth                       17/1999
# ethnicity                          Hispanic
# gender                                    F
# status                               FTGRAD
# entry_academic_period             Fall 2010
# exclusion_type                          NaN
# act_composite                          21.0
# act_math                                4.0
# act_english                              10
# act_reading                             7.0
# sat_combined                            NaN
# sat_math                                NaN
# sat_verbal                              NaN
# sat_reading                             NaN
# hs_gpa                                 2.54
# hs_city                              Denver
# hs_state                           Colorado
# hs_zip                              80033.0
# email                    fclark@example.com
# entry_age                              19.2
# ged                                   False
# english_2nd_language                   True
# first_generation                       True
# Name: 7, dtype: object
#
# 8 id                                 111119.0
# first_name                              Bob
# last_name                             Lopez
# date_of_birth                       04/1998
# ethnicity                             White
# gender                                    F
# status                                 FTFT
# entry_academic_period             Fall 2007
# exclusion_type                          NaN
# act_composite                          15.0
# act_math                                5.0
# act_english                               5
# act_reading                             5.0
# sat_combined                          720.0
# sat_math                              110.0
# sat_verbal                            400.0
# sat_reading                           220.0
# hs_gpa                                 3.24
# hs_city                              Denver
# hs_state                           Colorado
# hs_zip                              80122.0
# email                    blopez@example.com
# entry_age                              18.5
# ged                                   False
# english_2nd_language                  False
# first_generation                       True
# Name: 8, dtype: object
#
# 9 id                       NaN
# first_name               NaN
# last_name                NaN
# date_of_birth            NaN
# ethnicity                NaN
# gender                   NaN
# status                   NaN
# entry_academic_period    NaN
# exclusion_type           NaN
# act_composite            NaN
# act_math                 NaN
# act_english              NaN
# act_reading              NaN
# sat_combined             NaN
# sat_math                 NaN
# sat_verbal               NaN
# sat_reading              NaN
# hs_gpa                   NaN
# hs_city                  NaN
# hs_state                 NaN
# hs_zip                   NaN
# email                    NaN
# entry_age                NaN
# ged                      NaN
# english_2nd_language     NaN
# first_generation         NaN
# Name: 9, dtype: object

# %%
data3= {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}

df4 = pd.DataFrame(data3)

df4
# Out:
#      name  degree  score
# 0  aparna     MBA     90
# 1  pankaj     BCA     40
# 2  sudhir  M.Tech     80
# 3   Geeku     MBA     98

# %%
for key,value in df4.iterrows():
    print(key,value)
    print()
# Out:
# 0 name      aparna
# degree       MBA
# score         90
# Name: 0, dtype: object
#
# 1 name      pankaj
# degree       BCA
# score         40
# Name: 1, dtype: object
#
# 2 name      sudhir
# degree    M.Tech
# score         80
# Name: 2, dtype: object
#
# 3 name      Geeku
# degree      MBA
# score        98
# Name: 3, dtype: object

# %%
data4 = pd.read_csv(r'D:\excel_datas\day4\nba.csv')

data4.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
data5 = {'name':["aparna", "pankaj", "sudhir", "Geeku"],
        'degree': ["MBA", "BCA", "M.Tech", "MBA"],
        'score':[90, 40, 80, 98]}

df5 = pd.DataFrame(data5)

for i in df5.itertuples():
    print(i)
# Out:
# Pandas(Index=0, name='aparna', degree='MBA', score=90)
# Pandas(Index=1, name='pankaj', degree='BCA', score=40)
# Pandas(Index=2, name='sudhir', degree='M.Tech', score=80)
# Pandas(Index=3, name='Geeku', degree='MBA', score=98)

# %%
data6 = pd.read_csv(r'D:\excel_datas\day4\nba.csv')

df6 = pd.DataFrame(data6)

df6.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0  \
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
for i in df6.itertuples():
    print(i)
# Out:
# Pandas(Index=0, Name='Avery Bradley', Team='Boston Celtics', Number=0.0, Position='PG', Age=25.0, Height='6-2', Weight=180.0, College='Texas', Salary=7730337.0)
# Pandas(Index=1, Name='Jae Crowder', Team='Boston Celtics', Number=99.0, Position='SF', Age=25.0, Height='6-6', Weight=235.0, College='Marquette', Salary=6796117.0)
# Pandas(Index=2, Name='John Holland', Team='Boston Celtics', Number=30.0, Position='SG', Age=27.0, Height='6-5', Weight=205.0, College='Boston University', Salary=nan)
# Pandas(Index=3, Name='R.J. Hunter', Team='Boston Celtics', Number=28.0, Position='SG', Age=22.0, Height='6-5', Weight=185.0, College='Georgia State', Salary=1148640.0)
# Pandas(Index=4, Name='Jonas Jerebko', Team='Boston Celtics', Number=8.0, Position='PF', Age=29.0, Height='6-10', Weight=231.0, College=nan, Salary=5000000.0)
# Pandas(Index=5, Name='Amir Johnson', Team='Boston Celtics', Number=90.0, Position='PF', Age=29.0, Height='6-9', Weight=240.0, College=nan, Salary=12000000.0)
# Pandas(Index=6, Name='Jordan Mickey', Team='Boston Celtics', Number=55.0, Position='PF', Age=21.0, Height='6-8', Weight=235.0, College='LSU', Salary=1170960.0)
# Pandas(Index=7, Name='Kelly Olynyk', Team='Boston Celtics', Number=41.0, Position='C', Age=25.0, Height='7-0', Weight=238.0, College='Gonzaga', Salary=2165160.0)
# Pandas(Index=8, Name='Terry Rozier', Team='Boston Celtics', Number=12.0, Position='PG', Age=22.0, Height='6-2', Weight=190.0, College='Louisville', Salary=1824360.0)
# Pandas(Index=9, Name='Marcus Smart', Team='Boston Celtics', Number=36.0, Position='PG', Age=22.0, Height='6-4', Weight=220.0, College='Oklahoma State', Salary=3431040.0)
# Pandas(Index=10, Name='Jared Sullinger', Team='Boston Celtics', Number=7.0, Position='C', Age=24.0, Height='6-9', Weight=260.0, College='Ohio State', Salary=2569260.0)
# Pandas(Index=11, Name='Isaiah Thomas', Team='Boston Celtics', Number=4.0, Position='PG', Age=27.0, Height='5-9', Weight=185.0, College='Washington', Salary=6912869.0)
# Pandas(Index=12, Name='Evan Turner', Team='Boston Celtics', Number=11.0, Position='SG', Age=27.0, Height='6-7', Weight=220.0, College='Ohio State', Salary=3425510.0)
# Pandas(Index=13, Name='James Young', Team='Boston Celtics', Number=13.0, Position='SG', Age=20.0, Height='6-6', Weight=215.0, College='Kentucky', Salary=1749840.0)
# Pandas(Index=14, Name='Tyler Zeller', Team='Boston Celtics', Number=44.0, Position='C', Age=26.0, Height='7-0', Weight=253.0, College='North Carolina', Salary=2616975.0)
# Pandas(Index=15, Name='Bojan Bogdanovic', Team='Brooklyn Nets', Number=44.0, Position='SG', Age=27.0, Height='6-8', Weight=216.0, College=nan, Salary=3425510.0)
# Pandas(Index=16, Name='Markel Brown', Team='Brooklyn Nets', Number=22.0, Position='SG', Age=24.0, Height='6-3', Weight=190.0, College='Oklahoma State', Salary=845059.0)
# Pandas(Index=17, Name='Wayne Ellington', Team='Brooklyn Nets', Number=21.0, Position='SG', Age=28.0, Height='6-4', Weight=200.0, College='North Carolina', Salary=1500000.0)
# Pandas(Index=18, Name='Rondae Hollis-Jefferson', Team='Brooklyn Nets', Number=24.0, Position='SG', Age=21.0, Height='6-7', Weight=220.0, College='Arizona', Salary=1335480.0)
# Pandas(Index=19, Name='Jarrett Jack', Team='Brooklyn Nets', Number=2.0, Position='PG', Age=32.0, Height='6-3', Weight=200.0, College='Georgia Tech', Salary=6300000.0)
# Pandas(Index=20, Name='Sergey Karasev', Team='Brooklyn Nets', Number=10.0, Position='SG', Age=22.0, Height='6-7', Weight=208.0, College=nan, Salary=1599840.0)
# Pandas(Index=21, Name='Sean Kilpatrick', Team='Brooklyn Nets', Number=6.0, Position='SG', Age=26.0, Height='6-4', Weight=219.0, College='Cincinnati', Salary=134215.0)
# Pandas(Index=22, Name='Shane Larkin', Team='Brooklyn Nets', Number=0.0, Position='PG', Age=23.0, Height='5-11', Weight=175.0, College='Miami (FL)', Salary=1500000.0)
# Pandas(Index=23, Name='Brook Lopez', Team='Brooklyn Nets', Number=11.0, Position='C', Age=28.0, Height='7-0', Weight=275.0, College='Stanford', Salary=19689000.0)
# Pandas(Index=24, Name='Chris McCullough', Team='Brooklyn Nets', Number=1.0, Position='PF', Age=21.0, Height='6-11', Weight=200.0, College='Syracuse', Salary=1140240.0)
# Pandas(Index=25, Name='Willie Reed', Team='Brooklyn Nets', Number=33.0, Position='PF', Age=26.0, Height='6-10', Weight=220.0, College='Saint Louis', Salary=947276.0)
# Pandas(Index=26, Name='Thomas Robinson', Team='Brooklyn Nets', Number=41.0, Position='PF', Age=25.0, Height='6-10', Weight=237.0, College='Kansas', Salary=981348.0)
# Pandas(Index=27, Name='Henry Sims', Team='Brooklyn Nets', Number=14.0, Position='C', Age=26.0, Height='6-10', Weight=248.0, College='Georgetown', Salary=947276.0)
# Pandas(Index=28, Name='Donald Sloan', Team='Brooklyn Nets', Number=15.0, Position='PG', Age=28.0, Height='6-3', Weight=205.0, College='Texas A&M', Salary=947276.0)
# Pandas(Index=29, Name='Thaddeus Young', Team='Brooklyn Nets', Number=30.0, Position='PF', Age=27.0, Height='6-8', Weight=221.0, College='Georgia Tech', Salary=11235955.0)
# Pandas(Index=30, Name='Arron Afflalo', Team='New York Knicks', Number=4.0, Position='SG', Age=30.0, Height='6-5', Weight=210.0, College='UCLA', Salary=8000000.0)
# Pandas(Index=31, Name='Lou Amundson', Team='New York Knicks', Number=17.0, Position='PF', Age=33.0, Height='6-9', Weight=220.0, College='UNLV', Salary=1635476.0)
# Pandas(Index=32, Name='Thanasis Antetokounmpo', Team='New York Knicks', Number=43.0, Position='SF', Age=23.0, Height='6-7', Weight=205.0, College=nan, Salary=30888.0)
# Pandas(Index=33, Name='Carmelo Anthony', Team='New York Knicks', Number=7.0, Position='SF', Age=32.0, Height='6-8', Weight=240.0, College='Syracuse', Salary=22875000.0)
# Pandas(Index=34, Name='Jose Calderon', Team='New York Knicks', Number=3.0, Position='PG', Age=34.0, Height='6-3', Weight=200.0, College=nan, Salary=7402812.0)
# Pandas(Index=35, Name='Cleanthony Early', Team='New York Knicks', Number=11.0, Position='SF', Age=25.0, Height='6-8', Weight=210.0, College='Wichita State', Salary=845059.0)
# Pandas(Index=36, Name='Langston Galloway', Team='New York Knicks', Number=2.0, Position='SG', Age=24.0, Height='6-2', Weight=200.0, College="Saint Joseph's", Salary=845059.0)
# Pandas(Index=37, Name='Jerian Grant', Team='New York Knicks', Number=13.0, Position='PG', Age=23.0, Height='6-4', Weight=195.0, College='Notre Dame', Salary=1572360.0)
# Pandas(Index=38, Name='Robin Lopez', Team='New York Knicks', Number=8.0, Position='C', Age=28.0, Height='7-0', Weight=255.0, College='Stanford', Salary=12650000.0)
# Pandas(Index=39, Name="Kyle O'Quinn", Team='New York Knicks', Number=9.0, Position='PF', Age=26.0, Height='6-10', Weight=250.0, College='Norfolk State', Salary=3750000.0)
# Pandas(Index=40, Name='Kristaps Porzingis', Team='New York Knicks', Number=6.0, Position='PF', Age=20.0, Height='7-3', Weight=240.0, College=nan, Salary=4131720.0)
# Pandas(Index=41, Name='Kevin Seraphin', Team='New York Knicks', Number=1.0, Position='C', Age=26.0, Height='6-10', Weight=278.0, College=nan, Salary=2814000.0)
# Pandas(Index=42, Name='Lance Thomas', Team='New York Knicks', Number=42.0, Position='SF', Age=28.0, Height='6-8', Weight=235.0, College='Duke', Salary=1636842.0)
# Pandas(Index=43, Name='Sasha Vujacic', Team='New York Knicks', Number=18.0, Position='SG', Age=32.0, Height='6-7', Weight=195.0, College=nan, Salary=947276.0)
# Pandas(Index=44, Name='Derrick Williams', Team='New York Knicks', Number=23.0, Position='PF', Age=25.0, Height='6-8', Weight=240.0, College='Arizona', Salary=4000000.0)
# Pandas(Index=45, Name='Tony Wroten', Team='New York Knicks', Number=5.0, Position='SG', Age=23.0, Height='6-6', Weight=205.0, College='Washington', Salary=167406.0)
# Pandas(Index=46, Name='Elton Brand', Team='Philadelphia 76ers', Number=42.0, Position='PF', Age=37.0, Height='6-9', Weight=254.0, College='Duke', Salary=nan)
# Pandas(Index=47, Name='Isaiah Canaan', Team='Philadelphia 76ers', Number=0.0, Position='PG', Age=25.0, Height='6-0', Weight=201.0, College='Murray State', Salary=947276.0)
# Pandas(Index=48, Name='Robert Covington', Team='Philadelphia 76ers', Number=33.0, Position='SF', Age=25.0, Height='6-9', Weight=215.0, College='Tennessee State', Salary=1000000.0)
# Pandas(Index=49, Name='Joel Embiid', Team='Philadelphia 76ers', Number=21.0, Position='C', Age=22.0, Height='7-0', Weight=250.0, College='Kansas', Salary=4626960.0)
# Pandas(Index=50, Name='Jerami Grant', Team='Philadelphia 76ers', Number=39.0, Position='SF', Age=22.0, Height='6-8', Weight=210.0, College='Syracuse', Salary=845059.0)
# Pandas(Index=51, Name='Richaun Holmes', Team='Philadelphia 76ers', Number=22.0, Position='PF', Age=22.0, Height='6-10', Weight=245.0, College='Bowling Green', Salary=1074169.0)
# Pandas(Index=52, Name='Carl Landry', Team='Philadelphia 76ers', Number=7.0, Position='PF', Age=32.0, Height='6-9', Weight=248.0, College='Purdue', Salary=6500000.0)
# Pandas(Index=53, Name='Kendall Marshall', Team='Philadelphia 76ers', Number=5.0, Position='PG', Age=24.0, Height='6-4', Weight=200.0, College='North Carolina', Salary=2144772.0)
# Pandas(Index=54, Name='T.J. McConnell', Team='Philadelphia 76ers', Number=12.0, Position='PG', Age=24.0, Height='6-2', Weight=200.0, College='Arizona', Salary=525093.0)
# Pandas(Index=55, Name='Nerlens Noel', Team='Philadelphia 76ers', Number=4.0, Position='PF', Age=22.0, Height='6-11', Weight=228.0, College='Kentucky', Salary=3457800.0)
# Pandas(Index=56, Name='Jahlil Okafor', Team='Philadelphia 76ers', Number=8.0, Position='C', Age=20.0, Height='6-11', Weight=275.0, College='Duke', Salary=4582680.0)
# Pandas(Index=57, Name='Ish Smith', Team='Philadelphia 76ers', Number=1.0, Position='PG', Age=27.0, Height='6-0', Weight=175.0, College='Wake Forest', Salary=947276.0)
# Pandas(Index=58, Name='Nik Stauskas', Team='Philadelphia 76ers', Number=11.0, Position='SG', Age=22.0, Height='6-6', Weight=205.0, College='Michigan', Salary=2869440.0)
# Pandas(Index=59, Name='Hollis Thompson', Team='Philadelphia 76ers', Number=31.0, Position='SG', Age=25.0, Height='6-8', Weight=206.0, College='Georgetown', Salary=947276.0)
# Pandas(Index=60, Name='Christian Wood', Team='Philadelphia 76ers', Number=35.0, Position='PF', Age=20.0, Height='6-11', Weight=220.0, College='UNLV', Salary=525093.0)
# Pandas(Index=61, Name='Bismack Biyombo', Team='Toronto Raptors', Number=8.0, Position='C', Age=23.0, Height='6-9', Weight=245.0, College=nan, Salary=2814000.0)
# Pandas(Index=62, Name='Bruno Caboclo', Team='Toronto Raptors', Number=20.0, Position='SF', Age=20.0, Height='6-9', Weight=205.0, College=nan, Salary=1524000.0)
# Pandas(Index=63, Name='DeMarre Carroll', Team='Toronto Raptors', Number=5.0, Position='SF', Age=29.0, Height='6-8', Weight=212.0, College='Missouri', Salary=13600000.0)
# Pandas(Index=64, Name='DeMar DeRozan', Team='Toronto Raptors', Number=10.0, Position='SG', Age=26.0, Height='6-7', Weight=220.0, College='USC', Salary=10050000.0)
# Pandas(Index=65, Name='James Johnson', Team='Toronto Raptors', Number=3.0, Position='PF', Age=29.0, Height='6-9', Weight=250.0, College='Wake Forest', Salary=2500000.0)
# Pandas(Index=66, Name='Cory Joseph', Team='Toronto Raptors', Number=6.0, Position='PG', Age=24.0, Height='6-3', Weight=190.0, College='Texas', Salary=7000000.0)
# Pandas(Index=67, Name='Kyle Lowry', Team='Toronto Raptors', Number=7.0, Position='PG', Age=30.0, Height='6-0', Weight=205.0, College='Villanova', Salary=12000000.0)
# Pandas(Index=68, Name='Lucas Nogueira', Team='Toronto Raptors', Number=92.0, Position='C', Age=23.0, Height='7-0', Weight=220.0, College=nan, Salary=1842000.0)
# Pandas(Index=69, Name='Patrick Patterson', Team='Toronto Raptors', Number=54.0, Position='PF', Age=27.0, Height='6-9', Weight=235.0, College='Kentucky', Salary=6268675.0)
# Pandas(Index=70, Name='Norman Powell', Team='Toronto Raptors', Number=24.0, Position='SG', Age=23.0, Height='6-4', Weight=215.0, College='UCLA', Salary=650000.0)
# Pandas(Index=71, Name='Terrence Ross', Team='Toronto Raptors', Number=31.0, Position='SF', Age=25.0, Height='6-7', Weight=195.0, College='Washington', Salary=3553917.0)
# Pandas(Index=72, Name='Luis Scola', Team='Toronto Raptors', Number=4.0, Position='PF', Age=36.0, Height='6-9', Weight=240.0, College=nan, Salary=2900000.0)
# Pandas(Index=73, Name='Jason Thompson', Team='Toronto Raptors', Number=1.0, Position='PF', Age=29.0, Height='6-11', Weight=250.0, College='Rider', Salary=245177.0)
# Pandas(Index=74, Name='Jonas Valanciunas', Team='Toronto Raptors', Number=17.0, Position='C', Age=24.0, Height='7-0', Weight=255.0, College=nan, Salary=4660482.0)
# Pandas(Index=75, Name='Delon Wright', Team='Toronto Raptors', Number=55.0, Position='PG', Age=24.0, Height='6-5', Weight=190.0, College='Utah', Salary=1509360.0)
# Pandas(Index=76, Name='Leandro Barbosa', Team='Golden State Warriors', Number=19.0, Position='SG', Age=33.0, Height='6-3', Weight=194.0, College=nan, Salary=2500000.0)
# Pandas(Index=77, Name='Harrison Barnes', Team='Golden State Warriors', Number=40.0, Position='SF', Age=24.0, Height='6-8', Weight=225.0, College='North Carolina', Salary=3873398.0)
# Pandas(Index=78, Name='Andrew Bogut', Team='Golden State Warriors', Number=12.0, Position='C', Age=31.0, Height='7-0', Weight=260.0, College='Utah', Salary=13800000.0)
# Pandas(Index=79, Name='Ian Clark', Team='Golden State Warriors', Number=21.0, Position='SG', Age=25.0, Height='6-3', Weight=175.0, College='Belmont', Salary=947276.0)
# Pandas(Index=80, Name='Stephen Curry', Team='Golden State Warriors', Number=30.0, Position='PG', Age=28.0, Height='6-3', Weight=190.0, College='Davidson', Salary=11370786.0)
# Pandas(Index=81, Name='Festus Ezeli', Team='Golden State Warriors', Number=31.0, Position='C', Age=26.0, Height='6-11', Weight=265.0, College='Vanderbilt', Salary=2008748.0)
# Pandas(Index=82, Name='Draymond Green', Team='Golden State Warriors', Number=23.0, Position='PF', Age=26.0, Height='6-7', Weight=230.0, College='Michigan State', Salary=14260870.0)
# Pandas(Index=83, Name='Andre Iguodala', Team='Golden State Warriors', Number=9.0, Position='SF', Age=32.0, Height='6-6', Weight=215.0, College='Arizona', Salary=11710456.0)
# Pandas(Index=84, Name='Shaun Livingston', Team='Golden State Warriors', Number=34.0, Position='PG', Age=30.0, Height='6-7', Weight=192.0, College=nan, Salary=5543725.0)
# Pandas(Index=85, Name='Kevon Looney', Team='Golden State Warriors', Number=36.0, Position='SF', Age=20.0, Height='6-9', Weight=220.0, College='UCLA', Salary=1131960.0)
# Pandas(Index=86, Name='James Michael McAdoo', Team='Golden State Warriors', Number=20.0, Position='SF', Age=23.0, Height='6-9', Weight=240.0, College='North Carolina', Salary=845059.0)
# Pandas(Index=87, Name='Brandon Rush', Team='Golden State Warriors', Number=4.0, Position='SF', Age=30.0, Height='6-6', Weight=220.0, College='Kansas', Salary=1270964.0)
# Pandas(Index=88, Name='Marreese Speights', Team='Golden State Warriors', Number=5.0, Position='C', Age=28.0, Height='6-10', Weight=255.0, College='Florida', Salary=3815000.0)
# Pandas(Index=89, Name='Klay Thompson', Team='Golden State Warriors', Number=11.0, Position='SG', Age=26.0, Height='6-7', Weight=215.0, College='Washington State', Salary=15501000.0)
# Pandas(Index=90, Name='Anderson Varejao', Team='Golden State Warriors', Number=18.0, Position='PF', Age=33.0, Height='6-11', Weight=273.0, College=nan, Salary=289755.0)
# Pandas(Index=91, Name='Cole Aldrich', Team='Los Angeles Clippers', Number=45.0, Position='C', Age=27.0, Height='6-11', Weight=250.0, College='Kansas', Salary=1100602.0)
# Pandas(Index=92, Name='Jeff Ayres', Team='Los Angeles Clippers', Number=19.0, Position='PF', Age=29.0, Height='6-9', Weight=250.0, College='Arizona State', Salary=111444.0)
# Pandas(Index=93, Name='Jamal Crawford', Team='Los Angeles Clippers', Number=11.0, Position='SG', Age=36.0, Height='6-5', Weight=195.0, College='Michigan', Salary=5675000.0)
# Pandas(Index=94, Name='Branden Dawson', Team='Los Angeles Clippers', Number=22.0, Position='SF', Age=23.0, Height='6-6', Weight=225.0, College='Michigan State', Salary=525093.0)
# Pandas(Index=95, Name='Jeff Green', Team='Los Angeles Clippers', Number=8.0, Position='SF', Age=29.0, Height='6-9', Weight=235.0, College='Georgetown', Salary=9650000.0)
# Pandas(Index=96, Name='Blake Griffin', Team='Los Angeles Clippers', Number=32.0, Position='PF', Age=27.0, Height='6-10', Weight=251.0, College='Oklahoma', Salary=18907726.0)
# Pandas(Index=97, Name='Wesley Johnson', Team='Los Angeles Clippers', Number=33.0, Position='SF', Age=28.0, Height='6-7', Weight=215.0, College='Syracuse', Salary=1100602.0)
# Pandas(Index=98, Name='DeAndre Jordan', Team='Los Angeles Clippers', Number=6.0, Position='C', Age=27.0, Height='6-11', Weight=265.0, College='Texas A&M', Salary=19689000.0)
# Pandas(Index=99, Name='Luc Richard Mbah a Moute', Team='Los Angeles Clippers', Number=12.0, Position='PF', Age=29.0, Height='6-8', Weight=230.0, College='UCLA', Salary=947276.0)
# Pandas(Index=100, Name='Chris Paul', Team='Los Angeles Clippers', Number=3.0, Position='PG', Age=31.0, Height='6-0', Weight=175.0, College='Wake Forest', Salary=21468695.0)
# Pandas(Index=101, Name='Paul Pierce', Team='Los Angeles Clippers', Number=34.0, Position='SF', Age=38.0, Height='6-7', Weight=235.0, College='Kansas', Salary=3376000.0)
# Pandas(Index=102, Name='Pablo Prigioni', Team='Los Angeles Clippers', Number=9.0, Position='PG', Age=39.0, Height='6-3', Weight=185.0, College=nan, Salary=947726.0)
# Pandas(Index=103, Name='JJ Redick', Team='Los Angeles Clippers', Number=4.0, Position='SG', Age=31.0, Height='6-4', Weight=190.0, College='Duke', Salary=7085000.0)
# Pandas(Index=104, Name='Austin Rivers', Team='Los Angeles Clippers', Number=25.0, Position='PG', Age=23.0, Height='6-4', Weight=200.0, College='Duke', Salary=3110796.0)
# Pandas(Index=105, Name='C.J. Wilcox', Team='Los Angeles Clippers', Number=30.0, Position='SG', Age=25.0, Height='6-5', Weight=195.0, College='Washington', Salary=1159680.0)
# Pandas(Index=106, Name='Brandon Bass', Team='Los Angeles Lakers', Number=2.0, Position='PF', Age=31.0, Height='6-8', Weight=250.0, College='LSU', Salary=3000000.0)
# Pandas(Index=107, Name='Tarik Black', Team='Los Angeles Lakers', Number=28.0, Position='C', Age=24.0, Height='6-9', Weight=250.0, College='Kansas', Salary=845059.0)
# Pandas(Index=108, Name='Anthony Brown', Team='Los Angeles Lakers', Number=3.0, Position='SF', Age=23.0, Height='6-7', Weight=210.0, College='Stanford', Salary=700000.0)
# Pandas(Index=109, Name='Kobe Bryant', Team='Los Angeles Lakers', Number=24.0, Position='SF', Age=37.0, Height='6-6', Weight=212.0, College=nan, Salary=25000000.0)
# Pandas(Index=110, Name='Jordan Clarkson', Team='Los Angeles Lakers', Number=6.0, Position='PG', Age=24.0, Height='6-5', Weight=194.0, College='Missouri', Salary=845059.0)
# Pandas(Index=111, Name='Roy Hibbert', Team='Los Angeles Lakers', Number=17.0, Position='C', Age=29.0, Height='7-2', Weight=270.0, College='Georgetown', Salary=15592217.0)
# Pandas(Index=112, Name='Marcelo Huertas', Team='Los Angeles Lakers', Number=9.0, Position='PG', Age=33.0, Height='6-3', Weight=200.0, College=nan, Salary=525093.0)
# Pandas(Index=113, Name='Ryan Kelly', Team='Los Angeles Lakers', Number=4.0, Position='PF', Age=25.0, Height='6-11', Weight=230.0, College='Duke', Salary=1724250.0)
# Pandas(Index=114, Name='Larry Nance Jr.', Team='Los Angeles Lakers', Number=7.0, Position='PF', Age=23.0, Height='6-9', Weight=230.0, College='Wyoming', Salary=1155600.0)
# Pandas(Index=115, Name='Julius Randle', Team='Los Angeles Lakers', Number=30.0, Position='PF', Age=21.0, Height='6-9', Weight=250.0, College='Kentucky', Salary=3132240.0)
# Pandas(Index=116, Name="D'Angelo Russell", Team='Los Angeles Lakers', Number=1.0, Position='PG', Age=20.0, Height='6-5', Weight=195.0, College='Ohio State', Salary=5103120.0)
# Pandas(Index=117, Name='Robert Sacre', Team='Los Angeles Lakers', Number=50.0, Position='C', Age=27.0, Height='7-0', Weight=270.0, College='Gonzaga', Salary=981348.0)
# Pandas(Index=118, Name='Louis Williams', Team='Los Angeles Lakers', Number=23.0, Position='SG', Age=29.0, Height='6-1', Weight=175.0, College=nan, Salary=7000000.0)
# Pandas(Index=119, Name='Metta World Peace', Team='Los Angeles Lakers', Number=37.0, Position='SF', Age=36.0, Height='6-7', Weight=260.0, College="St. John's", Salary=947276.0)
# Pandas(Index=120, Name='Nick Young', Team='Los Angeles Lakers', Number=0.0, Position='SF', Age=31.0, Height='6-7', Weight=210.0, College='USC', Salary=5219169.0)
# Pandas(Index=121, Name='Eric Bledsoe', Team='Phoenix Suns', Number=2.0, Position='PG', Age=26.0, Height='6-1', Weight=190.0, College='Kentucky', Salary=13500000.0)
# Pandas(Index=122, Name='Devin Booker', Team='Phoenix Suns', Number=1.0, Position='SG', Age=19.0, Height='6-6', Weight=206.0, College='Kentucky', Salary=2127840.0)
# Pandas(Index=123, Name='Chase Budinger', Team='Phoenix Suns', Number=10.0, Position='SF', Age=28.0, Height='6-7', Weight=209.0, College='Arizona', Salary=206192.0)
# Pandas(Index=124, Name='Tyson Chandler', Team='Phoenix Suns', Number=4.0, Position='C', Age=33.0, Height='7-1', Weight=240.0, College=nan, Salary=13000000.0)
# Pandas(Index=125, Name='Archie Goodwin', Team='Phoenix Suns', Number=20.0, Position='SG', Age=21.0, Height='6-5', Weight=200.0, College='Kentucky', Salary=1160160.0)
# Pandas(Index=126, Name='John Jenkins', Team='Phoenix Suns', Number=23.0, Position='SG', Age=25.0, Height='6-4', Weight=215.0, College='Vanderbilt', Salary=981348.0)
# Pandas(Index=127, Name='Brandon Knight', Team='Phoenix Suns', Number=3.0, Position='PG', Age=24.0, Height='6-3', Weight=189.0, College='Kentucky', Salary=13500000.0)
# Pandas(Index=128, Name='Alex Len', Team='Phoenix Suns', Number=21.0, Position='C', Age=22.0, Height='7-1', Weight=260.0, College='Maryland', Salary=3807120.0)
# Pandas(Index=129, Name='Jon Leuer', Team='Phoenix Suns', Number=30.0, Position='PF', Age=27.0, Height='6-10', Weight=228.0, College='Wisconsin', Salary=1035000.0)
# Pandas(Index=130, Name='Phil Pressey', Team='Phoenix Suns', Number=25.0, Position='PG', Age=25.0, Height='5-11', Weight=175.0, College='Missouri', Salary=55722.0)
# Pandas(Index=131, Name='Ronnie Price', Team='Phoenix Suns', Number=14.0, Position='PG', Age=32.0, Height='6-2', Weight=190.0, College='Utah Valley', Salary=947276.0)
# Pandas(Index=132, Name='Mirza Teletovic', Team='Phoenix Suns', Number=35.0, Position='PF', Age=30.0, Height='6-9', Weight=242.0, College=nan, Salary=5500000.0)
# Pandas(Index=133, Name='P.J. Tucker', Team='Phoenix Suns', Number=17.0, Position='SF', Age=31.0, Height='6-6', Weight=245.0, College='Texas', Salary=5500000.0)
# Pandas(Index=134, Name='T.J. Warren', Team='Phoenix Suns', Number=12.0, Position='SF', Age=22.0, Height='6-8', Weight=230.0, College='North Carolina State', Salary=2041080.0)
# Pandas(Index=135, Name='Alan Williams', Team='Phoenix Suns', Number=15.0, Position='C', Age=23.0, Height='6-8', Weight=260.0, College='UC Santa Barbara', Salary=83397.0)
# Pandas(Index=136, Name='Quincy Acy', Team='Sacramento Kings', Number=13.0, Position='SF', Age=25.0, Height='6-7', Weight=240.0, College='Baylor', Salary=981348.0)
# Pandas(Index=137, Name='James Anderson', Team='Sacramento Kings', Number=5.0, Position='SG', Age=27.0, Height='6-6', Weight=213.0, College='Oklahoma State', Salary=1015421.0)
# Pandas(Index=138, Name='Marco Belinelli', Team='Sacramento Kings', Number=3.0, Position='SG', Age=30.0, Height='6-5', Weight=210.0, College=nan, Salary=6060606.0)
# Pandas(Index=139, Name='Caron Butler', Team='Sacramento Kings', Number=31.0, Position='SF', Age=36.0, Height='6-7', Weight=228.0, College='Connecticut', Salary=1449187.0)
# Pandas(Index=140, Name='Omri Casspi', Team='Sacramento Kings', Number=18.0, Position='SF', Age=27.0, Height='6-9', Weight=225.0, College=nan, Salary=2836186.0)
# Pandas(Index=141, Name='Willie Cauley-Stein', Team='Sacramento Kings', Number=0.0, Position='C', Age=22.0, Height='7-0', Weight=240.0, College='Kentucky', Salary=3398280.0)
# Pandas(Index=142, Name='Darren Collison', Team='Sacramento Kings', Number=7.0, Position='PG', Age=28.0, Height='6-0', Weight=175.0, College='UCLA', Salary=5013559.0)
# Pandas(Index=143, Name='DeMarcus Cousins', Team='Sacramento Kings', Number=15.0, Position='C', Age=25.0, Height='6-11', Weight=270.0, College='Kentucky', Salary=15851950.0)
# Pandas(Index=144, Name='Seth Curry', Team='Sacramento Kings', Number=30.0, Position='SG', Age=25.0, Height='6-2', Weight=185.0, College='Duke', Salary=947276.0)
# Pandas(Index=145, Name='Duje Dukan', Team='Sacramento Kings', Number=26.0, Position='PF', Age=24.0, Height='6-9', Weight=220.0, College='Wisconsin', Salary=525093.0)
# Pandas(Index=146, Name='Rudy Gay', Team='Sacramento Kings', Number=8.0, Position='SF', Age=29.0, Height='6-8', Weight=230.0, College='Connecticut', Salary=12403101.0)
# Pandas(Index=147, Name='Kosta Koufos', Team='Sacramento Kings', Number=41.0, Position='C', Age=27.0, Height='7-0', Weight=265.0, College='Ohio State', Salary=7700000.0)
# Pandas(Index=148, Name='Ben McLemore', Team='Sacramento Kings', Number=23.0, Position='SG', Age=23.0, Height='6-5', Weight=195.0, College='Kansas', Salary=3156600.0)
# Pandas(Index=149, Name='Eric Moreland', Team='Sacramento Kings', Number=25.0, Position='PF', Age=24.0, Height='6-10', Weight=238.0, College='Oregon State', Salary=845059.0)
# Pandas(Index=150, Name='Rajon Rondo', Team='Sacramento Kings', Number=9.0, Position='PG', Age=30.0, Height='6-1', Weight=186.0, College='Kentucky', Salary=9500000.0)
# Pandas(Index=151, Name='Cameron Bairstow', Team='Chicago Bulls', Number=41.0, Position='PF', Age=25.0, Height='6-9', Weight=250.0, College='New Mexico', Salary=845059.0)
# Pandas(Index=152, Name='Aaron Brooks', Team='Chicago Bulls', Number=0.0, Position='PG', Age=31.0, Height='6-0', Weight=161.0, College='Oregon', Salary=2250000.0)
# Pandas(Index=153, Name='Jimmy Butler', Team='Chicago Bulls', Number=21.0, Position='SG', Age=26.0, Height='6-7', Weight=220.0, College='Marquette', Salary=16407500.0)
# Pandas(Index=154, Name='Mike Dunleavy', Team='Chicago Bulls', Number=34.0, Position='SG', Age=35.0, Height='6-9', Weight=230.0, College='Duke', Salary=4500000.0)
# Pandas(Index=155, Name='Cristiano Felicio', Team='Chicago Bulls', Number=6.0, Position='PF', Age=23.0, Height='6-10', Weight=275.0, College=nan, Salary=525093.0)
# Pandas(Index=156, Name='Pau Gasol', Team='Chicago Bulls', Number=16.0, Position='C', Age=35.0, Height='7-0', Weight=250.0, College=nan, Salary=7448760.0)
# Pandas(Index=157, Name='Taj Gibson', Team='Chicago Bulls', Number=22.0, Position='PF', Age=30.0, Height='6-9', Weight=225.0, College='USC', Salary=8500000.0)
# Pandas(Index=158, Name='Justin Holiday', Team='Chicago Bulls', Number=7.0, Position='SG', Age=27.0, Height='6-6', Weight=185.0, College='Washington', Salary=947276.0)
# Pandas(Index=159, Name='Doug McDermott', Team='Chicago Bulls', Number=3.0, Position='SF', Age=24.0, Height='6-8', Weight=225.0, College='Creighton', Salary=2380440.0)
# Pandas(Index=160, Name='Nikola Mirotic', Team='Chicago Bulls', Number=44.0, Position='PF', Age=25.0, Height='6-10', Weight=220.0, College=nan, Salary=5543725.0)
# Pandas(Index=161, Name="E'Twaun Moore", Team='Chicago Bulls', Number=55.0, Position='SG', Age=27.0, Height='6-4', Weight=191.0, College='Purdue', Salary=1015421.0)
# Pandas(Index=162, Name='Joakim Noah', Team='Chicago Bulls', Number=13.0, Position='C', Age=31.0, Height='6-11', Weight=232.0, College='Florida', Salary=13400000.0)
# Pandas(Index=163, Name='Bobby Portis', Team='Chicago Bulls', Number=5.0, Position='PF', Age=21.0, Height='6-11', Weight=230.0, College='Arkansas', Salary=1391160.0)
# Pandas(Index=164, Name='Derrick Rose', Team='Chicago Bulls', Number=1.0, Position='PG', Age=27.0, Height='6-3', Weight=190.0, College='Memphis', Salary=20093064.0)
# Pandas(Index=165, Name='Tony Snell', Team='Chicago Bulls', Number=20.0, Position='SF', Age=24.0, Height='6-7', Weight=200.0, College='New Mexico', Salary=1535880.0)
# Pandas(Index=166, Name='Matthew Dellavedova', Team='Cleveland Cavaliers', Number=8.0, Position='PG', Age=25.0, Height='6-4', Weight=198.0, College="Saint Mary's", Salary=1147276.0)
# Pandas(Index=167, Name='Channing Frye', Team='Cleveland Cavaliers', Number=9.0, Position='PF', Age=33.0, Height='6-11', Weight=255.0, College='Arizona', Salary=8193029.0)
# Pandas(Index=168, Name='Kyrie Irving', Team='Cleveland Cavaliers', Number=2.0, Position='PG', Age=24.0, Height='6-3', Weight=193.0, College='Duke', Salary=16407501.0)
# Pandas(Index=169, Name='LeBron James', Team='Cleveland Cavaliers', Number=23.0, Position='SF', Age=31.0, Height='6-8', Weight=250.0, College=nan, Salary=22970500.0)
# Pandas(Index=170, Name='Richard Jefferson', Team='Cleveland Cavaliers', Number=24.0, Position='SF', Age=35.0, Height='6-7', Weight=233.0, College='Arizona', Salary=947276.0)
# Pandas(Index=171, Name='Dahntay Jones', Team='Cleveland Cavaliers', Number=30.0, Position='SG', Age=35.0, Height='6-6', Weight=225.0, College='Duke', Salary=nan)
# Pandas(Index=172, Name='James Jones', Team='Cleveland Cavaliers', Number=1.0, Position='SG', Age=35.0, Height='6-8', Weight=218.0, College='Miami (FL)', Salary=947276.0)
# Pandas(Index=173, Name='Sasha Kaun', Team='Cleveland Cavaliers', Number=14.0, Position='C', Age=31.0, Height='6-11', Weight=260.0, College='Kansas', Salary=1276000.0)
# Pandas(Index=174, Name='Kevin Love', Team='Cleveland Cavaliers', Number=0.0, Position='PF', Age=27.0, Height='6-10', Weight=251.0, College='UCLA', Salary=19689000.0)
# Pandas(Index=175, Name='Jordan McRae', Team='Cleveland Cavaliers', Number=12.0, Position='SG', Age=25.0, Height='6-5', Weight=179.0, College='Tennessee', Salary=111196.0)
# Pandas(Index=176, Name='Timofey Mozgov', Team='Cleveland Cavaliers', Number=20.0, Position='C', Age=29.0, Height='7-1', Weight=275.0, College=nan, Salary=4950000.0)
# Pandas(Index=177, Name='Iman Shumpert', Team='Cleveland Cavaliers', Number=4.0, Position='SG', Age=25.0, Height='6-5', Weight=220.0, College='Georgia Tech', Salary=8988765.0)
# Pandas(Index=178, Name='J.R. Smith', Team='Cleveland Cavaliers', Number=5.0, Position='SG', Age=30.0, Height='6-6', Weight=225.0, College=nan, Salary=5000000.0)
# Pandas(Index=179, Name='Tristan Thompson', Team='Cleveland Cavaliers', Number=13.0, Position='C', Age=25.0, Height='6-9', Weight=238.0, College='Texas', Salary=14260870.0)
# Pandas(Index=180, Name='Mo Williams', Team='Cleveland Cavaliers', Number=52.0, Position='PG', Age=33.0, Height='6-1', Weight=198.0, College='Alabama', Salary=2100000.0)
# Pandas(Index=181, Name='Joel Anthony', Team='Detroit Pistons', Number=50.0, Position='C', Age=33.0, Height='6-9', Weight=245.0, College='UNLV', Salary=2500000.0)
# Pandas(Index=182, Name='Aron Baynes', Team='Detroit Pistons', Number=12.0, Position='C', Age=29.0, Height='6-10', Weight=260.0, College='Washington State', Salary=6500000.0)
# Pandas(Index=183, Name='Steve Blake', Team='Detroit Pistons', Number=22.0, Position='PG', Age=36.0, Height='6-3', Weight=172.0, College='Maryland', Salary=2170465.0)
# Pandas(Index=184, Name='Lorenzo Brown', Team='Detroit Pistons', Number=17.0, Position='PG', Age=25.0, Height='6-5', Weight=189.0, College='North Carolina State', Salary=111444.0)
# Pandas(Index=185, Name='Reggie Bullock', Team='Detroit Pistons', Number=25.0, Position='SF', Age=25.0, Height='6-7', Weight=205.0, College='North Carolina', Salary=1252440.0)
# Pandas(Index=186, Name='Kentavious Caldwell-Pope', Team='Detroit Pistons', Number=5.0, Position='SG', Age=23.0, Height='6-5', Weight=205.0, College='Georgia', Salary=2891760.0)
# Pandas(Index=187, Name='Spencer Dinwiddie', Team='Detroit Pistons', Number=8.0, Position='PG', Age=23.0, Height='6-6', Weight=200.0, College='Colorado', Salary=845059.0)
# Pandas(Index=188, Name='Andre Drummond', Team='Detroit Pistons', Number=0.0, Position='C', Age=22.0, Height='6-11', Weight=279.0, College='Connecticut', Salary=3272091.0)
# Pandas(Index=189, Name='Tobias Harris', Team='Detroit Pistons', Number=34.0, Position='SF', Age=23.0, Height='6-9', Weight=235.0, College='Tennessee', Salary=16000000.0)
# Pandas(Index=190, Name='Darrun Hilliard', Team='Detroit Pistons', Number=6.0, Position='SF', Age=23.0, Height='6-6', Weight=205.0, College='Villanova', Salary=600000.0)
# Pandas(Index=191, Name='Reggie Jackson', Team='Detroit Pistons', Number=1.0, Position='PG', Age=26.0, Height='6-3', Weight=208.0, College='Boston College', Salary=13913044.0)
# Pandas(Index=192, Name='Stanley Johnson', Team='Detroit Pistons', Number=3.0, Position='SF', Age=20.0, Height='6-7', Weight=245.0, College='Arizona', Salary=2841960.0)
# Pandas(Index=193, Name='Jodie Meeks', Team='Detroit Pistons', Number=20.0, Position='SG', Age=28.0, Height='6-4', Weight=210.0, College='Kentucky', Salary=6270000.0)
# Pandas(Index=194, Name='Marcus Morris', Team='Detroit Pistons', Number=13.0, Position='PF', Age=26.0, Height='6-9', Weight=235.0, College='Kansas', Salary=5000000.0)
# Pandas(Index=195, Name='Anthony Tolliver', Team='Detroit Pistons', Number=43.0, Position='PF', Age=31.0, Height='6-8', Weight=240.0, College='Creighton', Salary=3000000.0)
# Pandas(Index=196, Name='Lavoy Allen', Team='Indiana Pacers', Number=5.0, Position='PF', Age=27.0, Height='6-9', Weight=255.0, College='Temple', Salary=4050000.0)
# Pandas(Index=197, Name='Rakeem Christmas', Team='Indiana Pacers', Number=25.0, Position='PF', Age=24.0, Height='6-9', Weight=250.0, College='Syracuse', Salary=1007026.0)
# Pandas(Index=198, Name='Monta Ellis', Team='Indiana Pacers', Number=11.0, Position='SG', Age=30.0, Height='6-3', Weight=185.0, College=nan, Salary=10300000.0)
# Pandas(Index=199, Name='Paul George', Team='Indiana Pacers', Number=13.0, Position='SF', Age=26.0, Height='6-9', Weight=220.0, College='Fresno State', Salary=17120106.0)
# Pandas(Index=200, Name='George Hill', Team='Indiana Pacers', Number=3.0, Position='PG', Age=30.0, Height='6-3', Weight=188.0, College='IUPUI', Salary=8000000.0)
# Pandas(Index=201, Name='Jordan Hill', Team='Indiana Pacers', Number=27.0, Position='C', Age=28.0, Height='6-10', Weight=235.0, College='Arizona', Salary=4000000.0)
# Pandas(Index=202, Name='Solomon Hill', Team='Indiana Pacers', Number=44.0, Position='SF', Age=25.0, Height='6-7', Weight=225.0, College='Arizona', Salary=1358880.0)
# Pandas(Index=203, Name='Ty Lawson', Team='Indiana Pacers', Number=10.0, Position='PG', Age=28.0, Height='5-11', Weight=195.0, College='North Carolina', Salary=211744.0)
# Pandas(Index=204, Name='Ian Mahinmi', Team='Indiana Pacers', Number=28.0, Position='C', Age=29.0, Height='6-11', Weight=250.0, College=nan, Salary=4000000.0)
# Pandas(Index=205, Name='C.J. Miles', Team='Indiana Pacers', Number=0.0, Position='SF', Age=29.0, Height='6-6', Weight=231.0, College=nan, Salary=4394225.0)
# Pandas(Index=206, Name='Glenn Robinson III', Team='Indiana Pacers', Number=40.0, Position='SG', Age=22.0, Height='6-7', Weight=222.0, College='Michigan', Salary=1100000.0)
# Pandas(Index=207, Name='Rodney Stuckey', Team='Indiana Pacers', Number=2.0, Position='PG', Age=30.0, Height='6-5', Weight=205.0, College='Eastern Washington', Salary=7000000.0)
# Pandas(Index=208, Name='Myles Turner', Team='Indiana Pacers', Number=33.0, Position='PF', Age=20.0, Height='6-11', Weight=243.0, College='Texas', Salary=2357760.0)
# Pandas(Index=209, Name='Shayne Whittington', Team='Indiana Pacers', Number=42.0, Position='PF', Age=25.0, Height='6-11', Weight=250.0, College='Western Michigan', Salary=845059.0)
# Pandas(Index=210, Name='Joe Young', Team='Indiana Pacers', Number=1.0, Position='PG', Age=23.0, Height='6-2', Weight=180.0, College='Oregon', Salary=1007026.0)
# Pandas(Index=211, Name='Giannis Antetokounmpo', Team='Milwaukee Bucks', Number=34.0, Position='SF', Age=21.0, Height='6-11', Weight=222.0, College=nan, Salary=1953960.0)
# Pandas(Index=212, Name='Jerryd Bayless', Team='Milwaukee Bucks', Number=19.0, Position='PG', Age=27.0, Height='6-3', Weight=200.0, College='Arizona', Salary=3000000.0)
# Pandas(Index=213, Name='Michael Carter-Williams', Team='Milwaukee Bucks', Number=5.0, Position='PG', Age=24.0, Height='6-6', Weight=190.0, College='Syracuse', Salary=2399040.0)
# Pandas(Index=214, Name='Jared Cunningham', Team='Milwaukee Bucks', Number=9.0, Position='SG', Age=25.0, Height='6-4', Weight=195.0, College='Oregon State', Salary=947276.0)
# Pandas(Index=215, Name='Tyler Ennis', Team='Milwaukee Bucks', Number=11.0, Position='PG', Age=21.0, Height='6-3', Weight=194.0, College='Syracuse', Salary=1662360.0)
# Pandas(Index=216, Name='John Henson', Team='Milwaukee Bucks', Number=31.0, Position='PF', Age=25.0, Height='6-11', Weight=229.0, College='North Carolina', Salary=2943221.0)
# Pandas(Index=217, Name='Damien Inglis', Team='Milwaukee Bucks', Number=17.0, Position='SF', Age=21.0, Height='6-8', Weight=246.0, College=nan, Salary=855000.0)
# Pandas(Index=218, Name='O.J. Mayo', Team='Milwaukee Bucks', Number=3.0, Position='SG', Age=28.0, Height='6-5', Weight=210.0, College='USC', Salary=8000000.0)
# Pandas(Index=219, Name='Khris Middleton', Team='Milwaukee Bucks', Number=22.0, Position='SG', Age=24.0, Height='6-8', Weight=234.0, College='Texas A&M', Salary=14700000.0)
# Pandas(Index=220, Name='Greg Monroe', Team='Milwaukee Bucks', Number=15.0, Position='C', Age=26.0, Height='6-11', Weight=265.0, College='Georgetown', Salary=16407500.0)
# Pandas(Index=221, Name='Steve Novak', Team='Milwaukee Bucks', Number=6.0, Position='SF', Age=32.0, Height='6-10', Weight=225.0, College='Marquette', Salary=295327.0)
# Pandas(Index=222, Name="Johnny O'Bryant III", Team='Milwaukee Bucks', Number=77.0, Position='PF', Age=23.0, Height='6-9', Weight=257.0, College='LSU', Salary=845059.0)
# Pandas(Index=223, Name='Jabari Parker', Team='Milwaukee Bucks', Number=12.0, Position='PF', Age=21.0, Height='6-8', Weight=250.0, College='Duke', Salary=5152440.0)
# Pandas(Index=224, Name='Miles Plumlee', Team='Milwaukee Bucks', Number=18.0, Position='C', Age=27.0, Height='6-11', Weight=249.0, College='Duke', Salary=2109294.0)
# Pandas(Index=225, Name='Greivis Vasquez', Team='Milwaukee Bucks', Number=21.0, Position='PG', Age=29.0, Height='6-6', Weight=217.0, College='Maryland', Salary=6600000.0)
# Pandas(Index=226, Name='Rashad Vaughn', Team='Milwaukee Bucks', Number=20.0, Position='SG', Age=19.0, Height='6-6', Weight=202.0, College='UNLV', Salary=1733040.0)
# Pandas(Index=227, Name='Justin Anderson', Team='Dallas Mavericks', Number=1.0, Position='SG', Age=22.0, Height='6-6', Weight=228.0, College='Virginia', Salary=1449000.0)
# Pandas(Index=228, Name='J.J. Barea', Team='Dallas Mavericks', Number=5.0, Position='PG', Age=31.0, Height='6-0', Weight=185.0, College='Northeastern', Salary=4290000.0)
# Pandas(Index=229, Name='Jeremy Evans', Team='Dallas Mavericks', Number=21.0, Position='SF', Age=28.0, Height='6-9', Weight=200.0, College='Western Kentucky', Salary=1100602.0)
# Pandas(Index=230, Name='Raymond Felton', Team='Dallas Mavericks', Number=2.0, Position='PG', Age=31.0, Height='6-1', Weight=205.0, College='North Carolina', Salary=3950313.0)
# Pandas(Index=231, Name='Devin Harris', Team='Dallas Mavericks', Number=34.0, Position='PG', Age=33.0, Height='6-3', Weight=185.0, College='Wisconsin', Salary=4053446.0)
# Pandas(Index=232, Name='David Lee', Team='Dallas Mavericks', Number=42.0, Position='PF', Age=33.0, Height='6-9', Weight=245.0, College='Florida', Salary=2085671.0)
# Pandas(Index=233, Name='Wesley Matthews', Team='Dallas Mavericks', Number=23.0, Position='SG', Age=29.0, Height='6-5', Weight=220.0, College='Marquette', Salary=16407500.0)
# Pandas(Index=234, Name='JaVale McGee', Team='Dallas Mavericks', Number=11.0, Position='C', Age=28.0, Height='7-0', Weight=270.0, College='Nevada', Salary=1270964.0)
# Pandas(Index=235, Name='Salah Mejri', Team='Dallas Mavericks', Number=50.0, Position='C', Age=29.0, Height='7-2', Weight=245.0, College=nan, Salary=525093.0)
# Pandas(Index=236, Name='Dirk Nowitzki', Team='Dallas Mavericks', Number=41.0, Position='PF', Age=37.0, Height='7-0', Weight=245.0, College=nan, Salary=8333334.0)
# Pandas(Index=237, Name='Zaza Pachulia', Team='Dallas Mavericks', Number=27.0, Position='C', Age=32.0, Height='6-11', Weight=275.0, College=nan, Salary=5200000.0)
# Pandas(Index=238, Name='Chandler Parsons', Team='Dallas Mavericks', Number=25.0, Position='SF', Age=27.0, Height='6-10', Weight=230.0, College='Florida', Salary=15361500.0)
# Pandas(Index=239, Name='Dwight Powell', Team='Dallas Mavericks', Number=7.0, Position='PF', Age=24.0, Height='6-11', Weight=240.0, College='Stanford', Salary=845059.0)
# Pandas(Index=240, Name='Charlie Villanueva', Team='Dallas Mavericks', Number=3.0, Position='PF', Age=31.0, Height='6-11', Weight=232.0, College='Connecticut', Salary=947276.0)
# Pandas(Index=241, Name='Deron Williams', Team='Dallas Mavericks', Number=8.0, Position='PG', Age=31.0, Height='6-3', Weight=200.0, College='Illinois', Salary=5378974.0)
# Pandas(Index=242, Name='Trevor Ariza', Team='Houston Rockets', Number=1.0, Position='SF', Age=30.0, Height='6-8', Weight=215.0, College='UCLA', Salary=8193030.0)
# Pandas(Index=243, Name='Michael Beasley', Team='Houston Rockets', Number=8.0, Position='SF', Age=27.0, Height='6-10', Weight=235.0, College='Kansas State', Salary=306527.0)
# Pandas(Index=244, Name='Patrick Beverley', Team='Houston Rockets', Number=2.0, Position='PG', Age=27.0, Height='6-1', Weight=185.0, College='Arkansas', Salary=6486486.0)
# Pandas(Index=245, Name='Corey Brewer', Team='Houston Rockets', Number=33.0, Position='SG', Age=30.0, Height='6-9', Weight=186.0, College='Florida', Salary=8229375.0)
# Pandas(Index=246, Name='Clint Capela', Team='Houston Rockets', Number=15.0, Position='PF', Age=22.0, Height='6-10', Weight=240.0, College=nan, Salary=1242720.0)
# Pandas(Index=247, Name='Sam Dekker', Team='Houston Rockets', Number=7.0, Position='SF', Age=22.0, Height='6-9', Weight=230.0, College='Wisconsin', Salary=1646400.0)
# Pandas(Index=248, Name='Andrew Goudelock', Team='Houston Rockets', Number=0.0, Position='PG', Age=27.0, Height='6-3', Weight=200.0, College='Charleston', Salary=200600.0)
# Pandas(Index=249, Name='James Harden', Team='Houston Rockets', Number=13.0, Position='SG', Age=26.0, Height='6-5', Weight=220.0, College='Arizona State', Salary=15756438.0)
# Pandas(Index=250, Name='Montrezl Harrell', Team='Houston Rockets', Number=35.0, Position='PF', Age=22.0, Height='6-8', Weight=240.0, College='Louisville', Salary=1000000.0)
# Pandas(Index=251, Name='Dwight Howard', Team='Houston Rockets', Number=12.0, Position='C', Age=30.0, Height='6-11', Weight=265.0, College=nan, Salary=22359364.0)
# Pandas(Index=252, Name='Terrence Jones', Team='Houston Rockets', Number=6.0, Position='PF', Age=24.0, Height='6-9', Weight=252.0, College='Kentucky', Salary=2489530.0)
# Pandas(Index=253, Name='K.J. McDaniels', Team='Houston Rockets', Number=32.0, Position='SG', Age=23.0, Height='6-6', Weight=205.0, College='Clemson', Salary=3189794.0)
# Pandas(Index=254, Name='Donatas Motiejunas', Team='Houston Rockets', Number=20.0, Position='PF', Age=25.0, Height='7-0', Weight=222.0, College=nan, Salary=2288205.0)
# Pandas(Index=255, Name='Josh Smith', Team='Houston Rockets', Number=5.0, Position='C', Age=30.0, Height='6-9', Weight=225.0, College=nan, Salary=947276.0)
# Pandas(Index=256, Name='Jason Terry', Team='Houston Rockets', Number=31.0, Position='SG', Age=38.0, Height='6-2', Weight=185.0, College='Arizona', Salary=947276.0)
# Pandas(Index=257, Name='Jordan Adams', Team='Memphis Grizzlies', Number=3.0, Position='SG', Age=21.0, Height='6-5', Weight=209.0, College='UCLA', Salary=1404600.0)
# Pandas(Index=258, Name='Tony Allen', Team='Memphis Grizzlies', Number=9.0, Position='SG', Age=34.0, Height='6-4', Weight=213.0, College='Oklahoma State', Salary=5158539.0)
# Pandas(Index=259, Name='Chris Andersen', Team='Memphis Grizzlies', Number=7.0, Position='PF', Age=37.0, Height='6-10', Weight=245.0, College='Blinn College', Salary=5000000.0)
# Pandas(Index=260, Name='Matt Barnes', Team='Memphis Grizzlies', Number=22.0, Position='SF', Age=36.0, Height='6-7', Weight=226.0, College='UCLA', Salary=3542500.0)
# Pandas(Index=261, Name='Vince Carter', Team='Memphis Grizzlies', Number=15.0, Position='SG', Age=39.0, Height='6-6', Weight=220.0, College='North Carolina', Salary=4088019.0)
# Pandas(Index=262, Name='Mike Conley', Team='Memphis Grizzlies', Number=11.0, Position='PG', Age=28.0, Height='6-1', Weight=175.0, College='Ohio State', Salary=9588426.0)
# Pandas(Index=263, Name='Bryce Cotton', Team='Memphis Grizzlies', Number=8.0, Position='PG', Age=23.0, Height='6-1', Weight=165.0, College='Providence', Salary=700902.0)
# Pandas(Index=264, Name='Jordan Farmar', Team='Memphis Grizzlies', Number=4.0, Position='PG', Age=29.0, Height='6-2', Weight=180.0, College='UCLA', Salary=nan)
# Pandas(Index=265, Name='Marc Gasol', Team='Memphis Grizzlies', Number=33.0, Position='C', Age=31.0, Height='7-1', Weight=255.0, College=nan, Salary=19688000.0)
# Pandas(Index=266, Name='JaMychal Green', Team='Memphis Grizzlies', Number=0.0, Position='PF', Age=25.0, Height='6-9', Weight=227.0, College='Alabama', Salary=845059.0)
# Pandas(Index=267, Name='P.J. Hairston', Team='Memphis Grizzlies', Number=19.0, Position='SF', Age=23.0, Height='6-6', Weight=230.0, College='North Carolina', Salary=1201440.0)
# Pandas(Index=268, Name='Jarell Martin', Team='Memphis Grizzlies', Number=10.0, Position='PF', Age=22.0, Height='6-10', Weight=239.0, College='LSU', Salary=1230840.0)
# Pandas(Index=269, Name='Ray McCallum', Team='Memphis Grizzlies', Number=5.0, Position='PG', Age=24.0, Height='6-3', Weight=190.0, College='Detroit', Salary=nan)
# Pandas(Index=270, Name='Xavier Munford', Team='Memphis Grizzlies', Number=14.0, Position='PG', Age=24.0, Height='6-3', Weight=180.0, College='Rhode Island', Salary=nan)
# Pandas(Index=271, Name='Zach Randolph', Team='Memphis Grizzlies', Number=50.0, Position='PF', Age=34.0, Height='6-9', Weight=260.0, College='Michigan State', Salary=9638555.0)
# Pandas(Index=272, Name='Lance Stephenson', Team='Memphis Grizzlies', Number=1.0, Position='SF', Age=25.0, Height='6-5', Weight=230.0, College='Cincinnati', Salary=9000000.0)
# Pandas(Index=273, Name='Alex Stepheson', Team='Memphis Grizzlies', Number=35.0, Position='PF', Age=28.0, Height='6-10', Weight=270.0, College='USC', Salary=nan)
# Pandas(Index=274, Name='Brandan Wright', Team='Memphis Grizzlies', Number=34.0, Position='PF', Age=28.0, Height='6-10', Weight=210.0, College='North Carolina', Salary=5464000.0)
# Pandas(Index=275, Name='Alexis Ajinca', Team='New Orleans Pelicans', Number=42.0, Position='C', Age=28.0, Height='7-2', Weight=248.0, College=nan, Salary=4389607.0)
# Pandas(Index=276, Name='Ryan Anderson', Team='New Orleans Pelicans', Number=33.0, Position='PF', Age=28.0, Height='6-10', Weight=240.0, College='California', Salary=8500000.0)
# Pandas(Index=277, Name='Omer Asik', Team='New Orleans Pelicans', Number=3.0, Position='C', Age=29.0, Height='7-0', Weight=255.0, College=nan, Salary=9213483.0)
# Pandas(Index=278, Name='Luke Babbitt', Team='New Orleans Pelicans', Number=8.0, Position='SF', Age=26.0, Height='6-9', Weight=225.0, College='Nevada', Salary=1100602.0)
# Pandas(Index=279, Name='Norris Cole', Team='New Orleans Pelicans', Number=30.0, Position='PG', Age=27.0, Height='6-2', Weight=175.0, College='Cleveland State', Salary=3036927.0)
# Pandas(Index=280, Name='Dante Cunningham', Team='New Orleans Pelicans', Number=44.0, Position='PF', Age=29.0, Height='6-8', Weight=230.0, College='Villanova', Salary=2850000.0)
# Pandas(Index=281, Name='Anthony Davis', Team='New Orleans Pelicans', Number=23.0, Position='PF', Age=23.0, Height='6-10', Weight=253.0, College='Kentucky', Salary=7070730.0)
# Pandas(Index=282, Name='Bryce Dejean-Jones', Team='New Orleans Pelicans', Number=31.0, Position='SG', Age=23.0, Height='6-6', Weight=203.0, College='Iowa State', Salary=169883.0)
# Pandas(Index=283, Name='Toney Douglas', Team='New Orleans Pelicans', Number=16.0, Position='PG', Age=30.0, Height='6-2', Weight=195.0, College='Florida State', Salary=1164858.0)
# Pandas(Index=284, Name='James Ennis', Team='New Orleans Pelicans', Number=4.0, Position='SF', Age=25.0, Height='6-7', Weight=210.0, College='Long Beach State', Salary=845059.0)
# Pandas(Index=285, Name='Tyreke Evans', Team='New Orleans Pelicans', Number=1.0, Position='SG', Age=26.0, Height='6-6', Weight=220.0, College='Memphis', Salary=10734586.0)
# ...
# Pandas(Index=363, Name='Victor Oladipo', Team='Orlando Magic', Number=5.0, Position='SG', Age=24.0, Height='6-4', Weight=210.0, College='Indiana', Salary=5192520.0)
# Pandas(Index=364, Name='Elfrid Payton', Team='Orlando Magic', Number=4.0, Position='PG', Age=22.0, Height='6-4', Weight=185.0, College='Louisiana-Lafayette', Salary=2505720.0)
# Pandas(Index=365, Name='Jason Smith', Team='Orlando Magic', Number=14.0, Position='PF', Age=30.0, Height='7-0', Weight=240.0, College='Colorado State', Salary=4300000.0)
# Pandas(Index=366, Name='Nikola Vucevic', Team='Orlando Magic', Number=9.0, Position='C', Age=25.0, Height='7-0', Weight=260.0, College='USC', Salary=11250000.0)
# Pandas(Index=367, Name='C.J. Watson', Team='Orlando Magic', Number=32.0, Position='PG', Age=32.0, Height='6-2', Weight=175.0, College='Tennessee', Salary=5000000.0)
# Pandas(Index=368, Name='Alan Anderson', Team='Washington Wizards', Number=6.0, Position='SG', Age=33.0, Height='6-6', Weight=220.0, College='Michigan State', Salary=4000000.0)
# Pandas(Index=369, Name='Bradley Beal', Team='Washington Wizards', Number=3.0, Position='SG', Age=22.0, Height='6-5', Weight=207.0, College='Florida', Salary=5694674.0)
# Pandas(Index=370, Name='Jared Dudley', Team='Washington Wizards', Number=1.0, Position='SF', Age=30.0, Height='6-7', Weight=225.0, College='Boston College', Salary=4375000.0)
# Pandas(Index=371, Name='Jarell Eddie', Team='Washington Wizards', Number=8.0, Position='SG', Age=24.0, Height='6-7', Weight=218.0, College='Virginia Tech', Salary=561716.0)
# Pandas(Index=372, Name='Drew Gooden', Team='Washington Wizards', Number=90.0, Position='PF', Age=34.0, Height='6-10', Weight=250.0, College='Kansas', Salary=3300000.0)
# Pandas(Index=373, Name='Marcin Gortat', Team='Washington Wizards', Number=13.0, Position='C', Age=32.0, Height='6-11', Weight=240.0, College=nan, Salary=11217391.0)
# Pandas(Index=374, Name='JJ Hickson', Team='Washington Wizards', Number=21.0, Position='C', Age=27.0, Height='6-9', Weight=242.0, College='North Carolina State', Salary=273038.0)
# Pandas(Index=375, Name='Nene Hilario', Team='Washington Wizards', Number=42.0, Position='C', Age=33.0, Height='6-11', Weight=250.0, College=nan, Salary=13000000.0)
# Pandas(Index=376, Name='Markieff Morris', Team='Washington Wizards', Number=5.0, Position='PF', Age=26.0, Height='6-10', Weight=245.0, College='Kansas', Salary=8000000.0)
# Pandas(Index=377, Name='Kelly Oubre Jr.', Team='Washington Wizards', Number=12.0, Position='SF', Age=20.0, Height='6-7', Weight=205.0, College='Kansas', Salary=1920240.0)
# Pandas(Index=378, Name='Otto Porter Jr.', Team='Washington Wizards', Number=22.0, Position='SF', Age=23.0, Height='6-8', Weight=198.0, College='Georgetown', Salary=4662960.0)
# Pandas(Index=379, Name='Ramon Sessions', Team='Washington Wizards', Number=7.0, Position='PG', Age=30.0, Height='6-3', Weight=190.0, College='Nevada', Salary=2170465.0)
# Pandas(Index=380, Name='Garrett Temple', Team='Washington Wizards', Number=17.0, Position='SG', Age=30.0, Height='6-6', Weight=195.0, College='LSU', Salary=1100602.0)
# Pandas(Index=381, Name='Marcus Thornton', Team='Washington Wizards', Number=15.0, Position='SF', Age=29.0, Height='6-4', Weight=205.0, College='LSU', Salary=200600.0)
# Pandas(Index=382, Name='John Wall', Team='Washington Wizards', Number=2.0, Position='PG', Age=25.0, Height='6-4', Weight=195.0, College='Kentucky', Salary=15851950.0)
# Pandas(Index=383, Name='Darrell Arthur', Team='Denver Nuggets', Number=0.0, Position='PF', Age=28.0, Height='6-9', Weight=235.0, College='Kansas', Salary=2814000.0)
# Pandas(Index=384, Name='D.J. Augustin', Team='Denver Nuggets', Number=12.0, Position='PG', Age=28.0, Height='6-0', Weight=183.0, College='Texas', Salary=3000000.0)
# Pandas(Index=385, Name='Will Barton', Team='Denver Nuggets', Number=5.0, Position='SF', Age=25.0, Height='6-6', Weight=175.0, College='Memphis', Salary=3533333.0)
# Pandas(Index=386, Name='Wilson Chandler', Team='Denver Nuggets', Number=21.0, Position='SF', Age=29.0, Height='6-8', Weight=225.0, College='DePaul', Salary=10449438.0)
# Pandas(Index=387, Name='Kenneth Faried', Team='Denver Nuggets', Number=35.0, Position='PF', Age=26.0, Height='6-8', Weight=228.0, College='Morehead State', Salary=11235955.0)
# Pandas(Index=388, Name='Danilo Gallinari', Team='Denver Nuggets', Number=8.0, Position='SF', Age=27.0, Height='6-10', Weight=225.0, College=nan, Salary=14000000.0)
# Pandas(Index=389, Name='Gary Harris', Team='Denver Nuggets', Number=14.0, Position='SG', Age=21.0, Height='6-4', Weight=210.0, College='Michigan State', Salary=1584480.0)
# Pandas(Index=390, Name='Nikola Jokic', Team='Denver Nuggets', Number=15.0, Position='C', Age=21.0, Height='6-10', Weight=250.0, College=nan, Salary=1300000.0)
# Pandas(Index=391, Name='Joffrey Lauvergne', Team='Denver Nuggets', Number=77.0, Position='C', Age=24.0, Height='6-11', Weight=220.0, College=nan, Salary=1709719.0)
# Pandas(Index=392, Name='Mike Miller', Team='Denver Nuggets', Number=3.0, Position='SG', Age=36.0, Height='6-8', Weight=218.0, College='Florida', Salary=947276.0)
# Pandas(Index=393, Name='Emmanuel Mudiay', Team='Denver Nuggets', Number=0.0, Position='PG', Age=20.0, Height='6-5', Weight=200.0, College=nan, Salary=3102240.0)
# Pandas(Index=394, Name='Jameer Nelson', Team='Denver Nuggets', Number=1.0, Position='PG', Age=34.0, Height='6-0', Weight=190.0, College="Saint Joseph's", Salary=4345000.0)
# Pandas(Index=395, Name='Jusuf Nurkic', Team='Denver Nuggets', Number=23.0, Position='C', Age=21.0, Height='7-0', Weight=280.0, College=nan, Salary=1842000.0)
# Pandas(Index=396, Name='JaKarr Sampson', Team='Denver Nuggets', Number=9.0, Position='SG', Age=23.0, Height='6-9', Weight=214.0, College="St. John's", Salary=258489.0)
# Pandas(Index=397, Name='Axel Toupane', Team='Denver Nuggets', Number=6.0, Position='SG', Age=23.0, Height='6-7', Weight=210.0, College=nan, Salary=nan)
# Pandas(Index=398, Name='Nemanja Bjelica', Team='Minnesota Timberwolves', Number=88.0, Position='PF', Age=28.0, Height='6-10', Weight=240.0, College=nan, Salary=3950001.0)
# Pandas(Index=399, Name='Gorgui Dieng', Team='Minnesota Timberwolves', Number=5.0, Position='C', Age=26.0, Height='6-11', Weight=241.0, College='Louisville', Salary=1474440.0)
# Pandas(Index=400, Name='Kevin Garnett', Team='Minnesota Timberwolves', Number=21.0, Position='PF', Age=40.0, Height='6-11', Weight=240.0, College=nan, Salary=8500000.0)
# Pandas(Index=401, Name='Tyus Jones', Team='Minnesota Timberwolves', Number=1.0, Position='PG', Age=20.0, Height='6-2', Weight=195.0, College='Duke', Salary=1282080.0)
# Pandas(Index=402, Name='Zach LaVine', Team='Minnesota Timberwolves', Number=8.0, Position='PG', Age=21.0, Height='6-5', Weight=189.0, College='UCLA', Salary=2148360.0)
# Pandas(Index=403, Name='Shabazz Muhammad', Team='Minnesota Timberwolves', Number=15.0, Position='SF', Age=23.0, Height='6-6', Weight=223.0, College='UCLA', Salary=2056920.0)
# Pandas(Index=404, Name='Adreian Payne', Team='Minnesota Timberwolves', Number=33.0, Position='PF', Age=25.0, Height='6-10', Weight=237.0, College='Michigan State', Salary=1938840.0)
# Pandas(Index=405, Name='Nikola Pekovic', Team='Minnesota Timberwolves', Number=14.0, Position='C', Age=30.0, Height='6-11', Weight=307.0, College=nan, Salary=12100000.0)
# Pandas(Index=406, Name='Tayshaun Prince', Team='Minnesota Timberwolves', Number=12.0, Position='SF', Age=36.0, Height='6-9', Weight=212.0, College='Kentucky', Salary=947276.0)
# Pandas(Index=407, Name='Ricky Rubio', Team='Minnesota Timberwolves', Number=9.0, Position='PG', Age=25.0, Height='6-4', Weight=194.0, College=nan, Salary=12700000.0)
# Pandas(Index=408, Name='Damjan Rudez', Team='Minnesota Timberwolves', Number=10.0, Position='SF', Age=29.0, Height='6-9', Weight=230.0, College=nan, Salary=1149500.0)
# Pandas(Index=409, Name='Greg Smith', Team='Minnesota Timberwolves', Number=4.0, Position='PF', Age=25.0, Height='6-10', Weight=250.0, College='Fresno State', Salary=nan)
# Pandas(Index=410, Name='Karl-Anthony Towns', Team='Minnesota Timberwolves', Number=32.0, Position='C', Age=20.0, Height='7-0', Weight=244.0, College='Kentucky', Salary=5703600.0)
# Pandas(Index=411, Name='Andrew Wiggins', Team='Minnesota Timberwolves', Number=22.0, Position='SG', Age=21.0, Height='6-8', Weight=199.0, College='Kansas', Salary=5758680.0)
# Pandas(Index=412, Name='Steven Adams', Team='Oklahoma City Thunder', Number=12.0, Position='C', Age=22.0, Height='7-0', Weight=255.0, College='Pittsburgh', Salary=2279040.0)
# Pandas(Index=413, Name='Nick Collison', Team='Oklahoma City Thunder', Number=4.0, Position='PF', Age=35.0, Height='6-10', Weight=255.0, College='Kansas', Salary=3750000.0)
# Pandas(Index=414, Name='Kevin Durant', Team='Oklahoma City Thunder', Number=35.0, Position='SF', Age=27.0, Height='6-9', Weight=240.0, College='Texas', Salary=20158622.0)
# Pandas(Index=415, Name='Randy Foye', Team='Oklahoma City Thunder', Number=6.0, Position='SG', Age=32.0, Height='6-4', Weight=213.0, College='Villanova', Salary=3135000.0)
# Pandas(Index=416, Name='Josh Huestis', Team='Oklahoma City Thunder', Number=34.0, Position='SF', Age=24.0, Height='6-7', Weight=230.0, College='Stanford', Salary=1140240.0)
# Pandas(Index=417, Name='Serge Ibaka', Team='Oklahoma City Thunder', Number=9.0, Position='PF', Age=26.0, Height='6-10', Weight=245.0, College=nan, Salary=12250000.0)
# Pandas(Index=418, Name='Enes Kanter', Team='Oklahoma City Thunder', Number=11.0, Position='C', Age=24.0, Height='6-11', Weight=245.0, College='Kentucky', Salary=16407500.0)
# Pandas(Index=419, Name='Mitch McGary', Team='Oklahoma City Thunder', Number=33.0, Position='PF', Age=24.0, Height='6-10', Weight=255.0, College='Michigan', Salary=1463040.0)
# Pandas(Index=420, Name='Nazr Mohammed', Team='Oklahoma City Thunder', Number=13.0, Position='C', Age=38.0, Height='6-10', Weight=250.0, College='Kentucky', Salary=222888.0)
# Pandas(Index=421, Name='Anthony Morrow', Team='Oklahoma City Thunder', Number=2.0, Position='SG', Age=30.0, Height='6-5', Weight=210.0, College='Georgia Tech', Salary=3344000.0)
# Pandas(Index=422, Name='Cameron Payne', Team='Oklahoma City Thunder', Number=22.0, Position='PG', Age=21.0, Height='6-3', Weight=185.0, College='Murray State', Salary=2021520.0)
# Pandas(Index=423, Name='Andre Roberson', Team='Oklahoma City Thunder', Number=21.0, Position='SG', Age=24.0, Height='6-7', Weight=210.0, College='Colorado', Salary=1210800.0)
# Pandas(Index=424, Name='Kyle Singler', Team='Oklahoma City Thunder', Number=5.0, Position='SF', Age=28.0, Height='6-8', Weight=228.0, College='Duke', Salary=4500000.0)
# Pandas(Index=425, Name='Dion Waiters', Team='Oklahoma City Thunder', Number=3.0, Position='SG', Age=24.0, Height='6-4', Weight=220.0, College='Syracuse', Salary=5138430.0)
# Pandas(Index=426, Name='Russell Westbrook', Team='Oklahoma City Thunder', Number=0.0, Position='PG', Age=27.0, Height='6-3', Weight=200.0, College='UCLA', Salary=16744218.0)
# Pandas(Index=427, Name='Cliff Alexander', Team='Portland Trail Blazers', Number=34.0, Position='PF', Age=20.0, Height='6-8', Weight=240.0, College='Kansas', Salary=525093.0)
# Pandas(Index=428, Name='Al-Farouq Aminu', Team='Portland Trail Blazers', Number=8.0, Position='SF', Age=25.0, Height='6-9', Weight=215.0, College='Wake Forest', Salary=8042895.0)
# Pandas(Index=429, Name='Pat Connaughton', Team='Portland Trail Blazers', Number=5.0, Position='SG', Age=23.0, Height='6-5', Weight=206.0, College='Notre Dame', Salary=625093.0)
# Pandas(Index=430, Name='Allen Crabbe', Team='Portland Trail Blazers', Number=23.0, Position='SG', Age=24.0, Height='6-6', Weight=210.0, College='California', Salary=947276.0)
# Pandas(Index=431, Name='Ed Davis', Team='Portland Trail Blazers', Number=17.0, Position='C', Age=27.0, Height='6-10', Weight=240.0, College='North Carolina', Salary=6980802.0)
# Pandas(Index=432, Name='Maurice Harkless', Team='Portland Trail Blazers', Number=4.0, Position='SF', Age=23.0, Height='6-9', Weight=215.0, College="St. John's", Salary=2894059.0)
# Pandas(Index=433, Name='Gerald Henderson', Team='Portland Trail Blazers', Number=9.0, Position='SG', Age=28.0, Height='6-5', Weight=215.0, College='Duke', Salary=6000000.0)
# Pandas(Index=434, Name='Chris Kaman', Team='Portland Trail Blazers', Number=35.0, Position='C', Age=34.0, Height='7-0', Weight=265.0, College='Central Michigan', Salary=5016000.0)
# Pandas(Index=435, Name='Meyers Leonard', Team='Portland Trail Blazers', Number=11.0, Position='PF', Age=24.0, Height='7-1', Weight=245.0, College='Illinois', Salary=3075880.0)
# Pandas(Index=436, Name='Damian Lillard', Team='Portland Trail Blazers', Number=0.0, Position='PG', Age=25.0, Height='6-3', Weight=195.0, College='Weber State', Salary=4236287.0)
# Pandas(Index=437, Name='C.J. McCollum', Team='Portland Trail Blazers', Number=3.0, Position='SG', Age=24.0, Height='6-4', Weight=200.0, College='Lehigh', Salary=2525160.0)
# Pandas(Index=438, Name='Luis Montero', Team='Portland Trail Blazers', Number=44.0, Position='SG', Age=23.0, Height='6-7', Weight=185.0, College='Westchester CC', Salary=525093.0)
# Pandas(Index=439, Name='Mason Plumlee', Team='Portland Trail Blazers', Number=24.0, Position='C', Age=26.0, Height='6-11', Weight=235.0, College='Duke', Salary=1415520.0)
# Pandas(Index=440, Name='Brian Roberts', Team='Portland Trail Blazers', Number=2.0, Position='PG', Age=30.0, Height='6-1', Weight=173.0, College='Dayton', Salary=2854940.0)
# Pandas(Index=441, Name='Noah Vonleh', Team='Portland Trail Blazers', Number=21.0, Position='PF', Age=20.0, Height='6-9', Weight=240.0, College='Indiana', Salary=2637720.0)
# Pandas(Index=442, Name='Trevor Booker', Team='Utah Jazz', Number=33.0, Position='PF', Age=28.0, Height='6-8', Weight=228.0, College='Clemson', Salary=4775000.0)
# Pandas(Index=443, Name='Trey Burke', Team='Utah Jazz', Number=3.0, Position='PG', Age=23.0, Height='6-1', Weight=191.0, College='Michigan', Salary=2658240.0)
# Pandas(Index=444, Name='Alec Burks', Team='Utah Jazz', Number=10.0, Position='SG', Age=24.0, Height='6-6', Weight=214.0, College='Colorado', Salary=9463484.0)
# Pandas(Index=445, Name='Dante Exum', Team='Utah Jazz', Number=11.0, Position='PG', Age=20.0, Height='6-6', Weight=190.0, College=nan, Salary=3777720.0)
# Pandas(Index=446, Name='Derrick Favors', Team='Utah Jazz', Number=15.0, Position='PF', Age=24.0, Height='6-10', Weight=265.0, College='Georgia Tech', Salary=12000000.0)
# Pandas(Index=447, Name='Rudy Gobert', Team='Utah Jazz', Number=27.0, Position='C', Age=23.0, Height='7-1', Weight=245.0, College=nan, Salary=1175880.0)
# Pandas(Index=448, Name='Gordon Hayward', Team='Utah Jazz', Number=20.0, Position='SF', Age=26.0, Height='6-8', Weight=226.0, College='Butler', Salary=15409570.0)
# Pandas(Index=449, Name='Rodney Hood', Team='Utah Jazz', Number=5.0, Position='SG', Age=23.0, Height='6-8', Weight=206.0, College='Duke', Salary=1348440.0)
# Pandas(Index=450, Name='Joe Ingles', Team='Utah Jazz', Number=2.0, Position='SF', Age=28.0, Height='6-8', Weight=226.0, College=nan, Salary=2050000.0)
# Pandas(Index=451, Name='Chris Johnson', Team='Utah Jazz', Number=23.0, Position='SF', Age=26.0, Height='6-6', Weight=206.0, College='Dayton', Salary=981348.0)
# Pandas(Index=452, Name='Trey Lyles', Team='Utah Jazz', Number=41.0, Position='PF', Age=20.0, Height='6-10', Weight=234.0, College='Kentucky', Salary=2239800.0)
# Pandas(Index=453, Name='Shelvin Mack', Team='Utah Jazz', Number=8.0, Position='PG', Age=26.0, Height='6-3', Weight=203.0, College='Butler', Salary=2433333.0)
# Pandas(Index=454, Name='Raul Neto', Team='Utah Jazz', Number=25.0, Position='PG', Age=24.0, Height='6-1', Weight=179.0, College=nan, Salary=900000.0)
# Pandas(Index=455, Name='Tibor Pleiss', Team='Utah Jazz', Number=21.0, Position='C', Age=26.0, Height='7-3', Weight=256.0, College=nan, Salary=2900000.0)
# Pandas(Index=456, Name='Jeff Withey', Team='Utah Jazz', Number=24.0, Position='C', Age=26.0, Height='7-0', Weight=231.0, College='Kansas', Salary=947276.0)
# Pandas(Index=457, Name=nan, Team=nan, Number=nan, Position=nan, Age=nan, Height=nan, Weight=nan, College=nan, Salary=nan)

# %%
clmn = data6(df6)
for i in clmn:
    print(df6[i][2])
