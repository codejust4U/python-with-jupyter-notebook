# %% [markdown]
# # Underfitting

# %%
import matplotlib.pyplot as plt

# %%
X = [5,10,15,20,25,30,35,40]
y1 = [4,8,12,16,20,24,28,32]
y2 = [7,14,21,28,35,42,49,56]
X1 = [5,50]
Y1 = [5,50]

# %%
plt.scatter(X,y1)
plt.scatter(X,y2)
plt.plot(X1,Y1)
